# %% [markdown]
# # Úkol č. 1 - vizualizace dat a web scraping (do 11. října)
#
#   * V rámci tohoto úkolu musíte stáhnout dat z webu (tzv. _web scraping_, velmi základní) a následně data zpracovat a vizualizovat.
#   * Cílem bude stáhnout data ze serveru https://www.psp.cz/sqw/hlasovani.sqw?o=8 týkající hlasování současné poslanecké sněmovny, uložit tato data v tabulkovém formátu a pak vymyslet vizualizace a zobrazení dat, které umožní orientaci v těchto datech a zvýrazní zajímavé informace a zobrazit přehledně časový vývoj různých veličin.
#
# > **Úkoly jsou zadány tak, aby Vám daly prostor pro invenci. Vymyslet _jak přesně_ budete úkol řešit, je důležitou součástí zadání a originalita či nápaditost bude také hodnocena!**
#
# ## Data
#
#  * Měli byste stáhnout data ze všech hlasování současné poslanecké sněmovny (tj. od voleb v roce 2017) a to až na úroveň jednotlivých poslanců.
#  * Data by měla obsahovat i stručný popis toho, o jaké hlasování šlo.
#
# ## Pokyny k vypracování
#
# **Základní body zadání**, za jejichž (poctivé) vypracování získáte **8 bodů**:
#   * Strojově stáhněte data a uložte je do vhodného formátu, který se Vám bude dále dobře zpracovávat.
#   * **I když nemusíte mít sněmovnu rádi, snažte se nezahltit server a mezi požadavky na stránku mějte alespoň vteřinu mezeru.**
#   * V druhé části Vašeho Jupyter notebooku pracujte se staženými daty v souborech, které jsou výsledkem Vašeho stahovacího skriptu (aby opravující nemusel spouštět stahování z webu).
#   * S využitím vybraných nástrojů zpracujte data a vymyslete vizualizace a grafy, aby bylo vidět následující:
#     * Odchody a přeběhnutí poslanců mezi jednotlivými stranami.
#     * Jakou mají jednotliví poslanci docházku (účast na hlasování) a jak jsou na tom s docházkou strany jako celek.
#     * Jak často spolu jednotlivé strany hlasují ve shodě a jak často hlasují odlišně.
#     * Jak jsou poslanci jednotlivých stran jednotní v hlasování (jak často hlasují stejně, kdo jsou největší rebelové).
#
# **Další body zadání** za případné další body (můžete si vybrat, maximum bodů za úkol je každopádně 12 bodů):
#   * Ve vizualizacích a grafech nějak zachyťte časový vývoj (např. jak se mění docházka, shoda mezi stranami atp.).
#   * Najděte jednotlivé poslance, kteří se nejvíce shodují při svém hlasování či kteří mají co nejpodobnější účast na hlasování.
#   * Zkuste rozlišit v datech důležitá hlasování a zpracujte vizualizace (také) pro ně.
#   * Zkuste najít hlasování, kde poslanci hlasovali nejvíce jinak, než obvykle.
#
# ## Tipy a triky
#   * Balíčky iportujte na začátku notebooku (příp. na začátku scrapovací a pak na začátku vizualizační části).
#   * Využívejte markdown buňky (jako je ta, ve které je tento text) a naspisy, abyste usnadnily orientaci opravující(mu).
#   * Pečlivě si vybírejte grafy a vizualizace, aby co nejlépe vyjádřily to, co vyjádřit chcete. Doporučuji projít si pro inspiraci alespoň galerie balíčků `matplotlib` a `seaborn`.
#
# ## Poznámky k odevzdání
#
#   * Řiďte se pokyny ze stránky https://courses.fit.cvut.cz/BI-VZD/homeworks/index.html.
#   * Odevzdejte Jupyter Notebook (příp. doplněn skripty), ale i soubor(y) se staženými daty (ať opravující nemusí stahovat data).
#   * Opravující Vám může umožnit úkol dodělat či opravit a získat tak další body. První verze je ale důležitá a bude-li odbytá, budete za to penalizováni.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Bez násl. řádku někdy nefunguje vykreslování grafů v Jupyter noteboocích
# %matplotlib inline 
import matplotlib
matplotlib.style.use('ggplot')

# %%
dfMeeting = pd.read_csv("meeting.csv", encoding='windows-1250')
dfMeeting['votingDate'] = pd.to_datetime(dfMeeting['votingDate'], format='%d. %m. %Y %H:%M')
dfVote = pd.read_csv("vote.csv", encoding='windows-1250')
dfMeeting
# Out:
#       topicID                                          topicName  meetingNum  \
# 0           0    Inf. o ustavení volební komise PS a volbě členů           1
# 1           1    Inf. o ustavení volební komise PS a volbě členů           1
# 2           2                             Procedurální hlasování           1
# 3           3                     Náv.na stanovení počtu čl. MIV           1
# 4           4                     Náv.na stanovení počtu čl. MIV           1
# ...       ...                                                ...         ...
# 4936     4936  Novela z. o provozu vozidel na poz. komunikací...          39
# 4937     4937  Návrh na zřízení VK pro vyhodnocení vlivu auto...          39
# 4938     4938  Novela z. - občanský soudní řád (sněmovní tisk...          39
# 4939     4939                             Procedurální hlasování          39
# 4940     4940                             Procedurální hlasování          40
#
#               votingDate
# 0    2017-11-20 13:53:00
# 1    2017-11-20 13:53:00
# 2    2017-11-20 14:47:00
# 3    2017-11-20 15:39:00
# 4    2017-11-20 15:39:00
# ...                  ...
# 4936 2019-12-18 12:52:00
# 4937 2019-12-18 17:34:00
# 4938 2019-12-18 17:58:00
# 4939 2019-12-18 19:00:00
# 4940 2020-01-21 14:03:00
#
# [4941 rows x 4 columns]

# %% [markdown]
# Stažená data jsou v formatu .csv. Data jsem vytáhl pomocí skriptu scrapper.py. Jak lze vidět, tabulka má skoro 1milion záznamů. Jedná se o schůze 1-39. Samozrejmě lze stáhnou i zbytek, ale z časových a pamětových důvodů (VScode má problém otevřít takto velká soubor) jsem předčasně ukončil scrapování.
#
# Každý záznam tabulky dfMeeting ukládá jednotlivá témata hlasování. Jedná se o:
# * ID tematu:
# * Tema: stručný popis
# * meetingNum: číslo schůze během kterého se hlasovalo
# * votingDate: den a čas hlasování
#
# dfVote obsahuje:

# %% [markdown]
# Kvůli pamětovým problémům jsem musel pri skrappování rozdělit data do 2 souborů, to ale nevadí, pomocí merge můžeme data zpátky spojit

# %%
df = dfVote.merge(dfMeeting, on='topicID', how='left', right_index=True)
typesOfVotes = df['vote'].unique().tolist()
df
# Out:
#                                 name political party  topicID       vote  \
# 0                      Věra Adámková             ANO        0        yes
# 1                       Andrej Babiš             ANO        0        yes
# 2                    Andrea Babišová             ANO        0        yes
# 3                Margita Balaštíková             ANO        0        yes
# 4                       Josef Bělica             ANO        0        yes
# ...                              ...             ...      ...        ...
# 987395                  Marian Bojko         Nezařaz     4939    excused
# 987396                  Václav Klaus         Nezařaz     4939        yes
# 987397  Zuzana Majerová Zahradníková         Nezařaz     4939        yes
# 987398               Ivana Nevludová         Nezařaz     4939  refrained
# 987399                 Lubomír Volný         Nezařaz     4939    excused
#
#                                               topicName  meetingNum  \
# 0       Inf. o ustavení volební komise PS a volbě členů           1
# 1       Inf. o ustavení volební komise PS a volbě členů           1
# 2       Inf. o ustavení volební komise PS a volbě členů           1
# 3       Inf. o ustavení volební komise PS a volbě členů           1
# 4       Inf. o ustavení volební komise PS a volbě členů           1
# ...                                                 ...         ...
# 987395                           Procedurální hlasování          39
# 987396                           Procedurální hlasování          39
# 987397                           Procedurální hlasování          39
# 987398                           Procedurální hlasování          39
# 987399                           Procedurální hlasování          39
#
#                 votingDate
# 0      2017-11-20 13:53:00
# 1      2017-11-20 13:53:00
# 2      2017-11-20 13:53:00
# 3      2017-11-20 13:53:00
# 4      2017-11-20 13:53:00
# ...                    ...
# 987395 2019-12-18 19:00:00
# 987396 2019-12-18 19:00:00
# 987397 2019-12-18 19:00:00
# 987398 2019-12-18 19:00:00
# 987399 2019-12-18 19:00:00
#
# [987400 rows x 7 columns]

# %%
typesOfVotes
# Out:
# ['yes', 'refrained', 'not-logged-in', 'excused', 'no']

# %%
poslanci = df['name'].unique().tolist()
peopleThatChanged = set()
for poslanec in poslanci:
    poslanecDF = df[df['name'] == poslanec]
    parties = (poslanecDF['political party']).unique().tolist()
    if(len(parties) > 1):
        print(poslanec, parties)
        peopleThatChanged.add((poslanec, parties))

# %% [markdown]
# Jednoduchým filtrovaním můžeme zjistit výsledky jednotlivých hlasování

# %%
tmp = df[['votingDate', 'topicID', 'vote']]
d=[]
for i in tmp['topicID'].unique():
    topic= tmp[tmp['topicID'] == i]
    majority = (-1, "")
    for typeVote in typesOfVotes:
        amount = len(topic[topic['vote'] == typeVote].index)
        print(i, typeVote, amount)
        if amount > majority[0]:
            majority = (amount, typeVote)
    d.append((i, topic.iloc[0]['votingDate'], majority[1]))
    print('majority for topic ', i, ' voted for ', str(majority[1])  )
# Out:
# 0 yes 191
# 0 refrained 5
# 0 not-logged-in 3
# 0 excused 1
# 0 no 0
# majority for topic  0  voted for  yes
# 1 yes 194
# 1 refrained 4
# 1 not-logged-in 1
# 1 excused 1
# 1 no 0
# majority for topic  1  voted for  yes
# 2 yes 50
# 2 refrained 19
# 2 not-logged-in 1
# 2 excused 1
# 2 no 129
# majority for topic  2  voted for  no
# 3 yes 56
# 3 refrained 43
# 3 not-logged-in 0
# 3 excused 1
# 3 no 100
# majority for topic  3  voted for  no
# 4 yes 174
# 4 refrained 6
# 4 not-logged-in 0
# 4 excused 1
# 4 no 19
# majority for topic  4  voted for  yes
# 5 yes 189
# 5 refrained 1
# 5 not-logged-in 8
# 5 excused 2
# 5 no 0
# majority for topic  5  voted for  yes
# 6 yes 115
# 6 refrained 13
# 6 not-logged-in 5
# 6 excused 1
# 6 no 66
# majority for topic  6  voted for  yes
# 7 yes 188
# 7 refrained 7
# 7 not-logged-in 3
# 7 excused 1
# 7 no 1
# majority for topic  7  voted for  yes
# 8 yes 91
# 8 refrained 19
# 8 not-logged-in 8
# 8 excused 3
# 8 no 79
# majority for topic  8  voted for  yes
# 9 yes 146
# 9 refrained 27
# 9 not-logged-in 8
# 9 excused 3
# 9 no 16
# majority for topic  9  voted for  yes
# 10 yes 161
# 10 refrained 19
# 10 not-logged-in 16
# 10 excused 4
# 10 no 0
# majority for topic  10  voted for  yes
# 11 yes 179
# 11 refrained 9
# 11 not-logged-in 8
# 11 excused 4
# 11 no 0
# majority for topic  11  voted for  yes
# 12 yes 178
# 12 refrained 10
# 12 not-logged-in 8
# 12 excused 4
# 12 no 0
# majority for topic  12  voted for  yes
# 13 yes 183
# 13 refrained 5
# 13 not-logged-in 7
# 13 excused 5
# 13 no 0
# majority for topic  13  voted for  yes
# 14 yes 186
# 14 refrained 3
# 14 not-logged-in 6
# 14 excused 5
# 14 no 0
# majority for topic  14  voted for  yes
# 15 yes 177
# 15 refrained 11
# 15 not-logged-in 7
# 15 excused 5
# 15 no 0
# majority for topic  15  voted for  yes
# 16 yes 179
# 16 refrained 3
# 16 not-logged-in 8
# 16 excused 10
# 16 no 0
# majority for topic  16  voted for  yes
# 17 yes 183
# 17 refrained 2
# 17 not-logged-in 5
# 17 excused 10
# 17 no 0
# majority for topic  17  voted for  yes
# 18 yes 186
# 18 refrained 0
# 18 not-logged-in 4
# 18 excused 10
# 18 no 0
# majority for topic  18  voted for  yes
# 19 yes 181
# 19 refrained 9
# 19 not-logged-in 2
# 19 excused 8
# 19 no 0
# majority for topic  19  voted for  yes
# 20 yes 181
# 20 refrained 9
# 20 not-logged-in 2
# 20 excused 8
# 20 no 0
# majority for topic  20  voted for  yes
# 21 yes 181
# 21 refrained 9
# 21 not-logged-in 2
# 21 excused 8
# 21 no 0
# majority for topic  21  voted for  yes
# 22 yes 182
# 22 refrained 8
# 22 not-logged-in 2
# 22 excused 8
# 22 no 0
# majority for topic  22  voted for  yes
# 23 yes 184
# 23 refrained 6
# 23 not-logged-in 2
# 23 excused 8
# 23 no 0
# majority for topic  23  voted for  yes
# 24 yes 184
# 24 refrained 6
# 24 not-logged-in 2
# 24 excused 8
# 24 no 0
# majority for topic  24  voted for  yes
# 25 yes 185
# 25 refrained 5
# 25 not-logged-in 2
# 25 excused 8
# 25 no 0
# majority for topic  25  voted for  yes
# 26 yes 184
# 26 refrained 6
# 26 not-logged-in 2
# 26 excused 8
# 26 no 0
# majority for topic  26  voted for  yes
# 27 yes 186
# 27 refrained 4
# 27 not-logged-in 2
# 27 excused 8
# 27 no 0
# majority for topic  27  voted for  yes
# 28 yes 181
# 28 refrained 8
# 28 not-logged-in 2
# 28 excused 8
# 28 no 1
# majority for topic  28  voted for  yes
# 29 yes 186
# 29 refrained 4
# 29 not-logged-in 2
# 29 excused 8
# 29 no 0
# majority for topic  29  voted for  yes
# 30 yes 185
# 30 refrained 5
# 30 not-logged-in 2
# 30 excused 8
# 30 no 0
# majority for topic  30  voted for  yes
# 31 yes 186
# 31 refrained 4
# 31 not-logged-in 2
# 31 excused 8
# 31 no 0
# majority for topic  31  voted for  yes
# 32 yes 187
# 32 refrained 3
# 32 not-logged-in 2
# 32 excused 8
# 32 no 0
# majority for topic  32  voted for  yes
# 33 yes 185
# 33 refrained 5
# 33 not-logged-in 2
# 33 excused 8
# 33 no 0
# majority for topic  33  voted for  yes
# 34 yes 185
# 34 refrained 5
# 34 not-logged-in 2
# 34 excused 8
# 34 no 0
# majority for topic  34  voted for  yes
# 35 yes 187
# 35 refrained 3
# 35 not-logged-in 2
# 35 excused 8
# 35 no 0
# majority for topic  35  voted for  yes
# 36 yes 164
# 36 refrained 22
# 36 not-logged-in 4
# 36 excused 10
# 36 no 0
# majority for topic  36  voted for  yes
# 37 yes 38
# 37 refrained 135
# 37 not-logged-in 15
# 37 excused 12
# 37 no 0
# majority for topic  37  voted for  refrained
# 38 yes 45
# 38 refrained 131
# 38 not-logged-in 12
# 38 excused 12
# 38 no 0
# majority for topic  38  voted for  refrained
# 39 yes 93
# 39 refrained 81
# 39 not-logged-in 11
# 39 excused 12
# 39 no 3
# majority for topic  39  voted for  yes
# 40 yes 101
# 40 refrained 49
# 40 not-logged-in 9
# 40 excused 12
# 40 no 29
# majority for topic  40  voted for  yes
# 41 yes 169
# 41 refrained 13
# 41 not-logged-in 5
# 41 excused 12
# 41 no 1
# majority for topic  41  voted for  yes
# 42 yes 108
# 42 refrained 16
# 42 not-logged-in 5
# 42 excused 11
# 42 no 60
# majority for topic  42  voted for  yes
# 43 yes 2
# 43 refrained 182
# 43 not-logged-in 5
# 43 excused 11
# 43 no 0
# majority for topic  43  voted for  refrained
# 44 yes 68
# 44 refrained 13
# 44 not-logged-in 14
# 44 excused 12
# 44 no 93
# majority for topic  44  voted for  no
# 45 yes 108
# 45 refrained 14
# 45 not-logged-in 13
# 45 excused 12
# 45 no 53
# majority for topic  45  voted for  yes
# 46 yes 67
# 46 refrained 11
# 46 not-logged-in 14
# 46 excused 11
# 46 no 97
# majority for topic  46  voted for  no
# 47 yes 107
# 47 refrained 12
# 47 not-logged-in 14
# 47 excused 11
# 47 no 56
# majority for topic  47  voted for  yes
# 48 yes 70
# 48 refrained 9
# 48 not-logged-in 14
# 48 excused 11
# 48 no 96
# majority for topic  48  voted for  no
# 49 yes 106
# 49 refrained 15
# 49 not-logged-in 14
# 49 excused 11
# 49 no 54
# majority for topic  49  voted for  yes
# 50 yes 65
# 50 refrained 13
# 50 not-logged-in 14
# 50 excused 10
# 50 no 98
# majority for topic  50  voted for  no
# 51 yes 109
# 51 refrained 12
# 51 not-logged-in 14
# 51 excused 10
# 51 no 55
# majority for topic  51  voted for  yes
# 52 yes 65
# 52 refrained 10
# 52 not-logged-in 14
# 52 excused 10
# 52 no 101
# majority for topic  52  voted for  no
# 53 yes 108
# 53 refrained 11
# 53 not-logged-in 14
# 53 excused 10
# 53 no 57
# majority for topic  53  voted for  yes
# 54 yes 63
# 54 refrained 24
# 54 not-logged-in 14
# 54 excused 10
# 54 no 89
# majority for topic  54  voted for  no
# 55 yes 105
# 55 refrained 17
# 55 not-logged-in 13
# 55 excused 10
# 55 no 55
# majority for topic  55  voted for  yes
# 56 yes 61
# 56 refrained 21
# 56 not-logged-in 15
# 56 excused 10
# 56 no 93
# majority for topic  56  voted for  no
# 57 yes 99
# 57 refrained 25
# 57 not-logged-in 15
# 57 excused 10
# 57 no 51
# majority for topic  57  voted for  yes
# 58 yes 59
# 58 refrained 19
# 58 not-logged-in 15
# 58 excused 10
# 58 no 97
# majority for topic  58  voted for  no
# 59 yes 104
# 59 refrained 18
# 59 not-logged-in 15
# 59 excused 10
# 59 no 53
# majority for topic  59  voted for  yes
# 60 yes 63
# 60 refrained 16
# 60 not-logged-in 13
# 60 excused 10
# 60 no 98
# majority for topic  60  voted for  no
# 61 yes 108
# 61 refrained 12
# 61 not-logged-in 13
# 61 excused 10
# 61 no 57
# majority for topic  61  voted for  yes
# 62 yes 62
# 62 refrained 16
# 62 not-logged-in 13
# 62 excused 10
# 62 no 99
# majority for topic  62  voted for  no
# 63 yes 104
# 63 refrained 16
# 63 not-logged-in 13
# 63 excused 10
# 63 no 57
# majority for topic  63  voted for  yes
# 64 yes 146
# 64 refrained 23
# 64 not-logged-in 18
# 64 excused 10
# 64 no 3
# majority for topic  64  voted for  yes
# 65 yes 149
# 65 refrained 3
# 65 not-logged-in 38
# 65 excused 10
# 65 no 0
# majority for topic  65  voted for  yes
# 66 yes 149
# 66 refrained 4
# 66 not-logged-in 23
# 66 excused 24
# 66 no 0
# majority for topic  66  voted for  yes
# 67 yes 60
# 67 refrained 107
# 67 not-logged-in 8
# 67 excused 24
# 67 no 1
# majority for topic  67  voted for  refrained
# 68 yes 79
# 68 refrained 20
# 68 not-logged-in 9
# 68 excused 24
# 68 no 68
# majority for topic  68  voted for  yes
# 69 yes 166
# 69 refrained 4
# 69 not-logged-in 6
# 69 excused 24
# 69 no 0
# majority for topic  69  voted for  yes
# 70 yes 168
# 70 refrained 3
# 70 not-logged-in 5
# 70 excused 24
# 70 no 0
# majority for topic  70  voted for  yes
# 71 yes 153
# 71 refrained 17
# 71 not-logged-in 5
# 71 excused 24
# 71 no 1
# majority for topic  71  voted for  yes
# 72 yes 168
# 72 refrained 3
# 72 not-logged-in 5
# 72 excused 24
# 72 no 0
# majority for topic  72  voted for  yes
# 73 yes 167
# 73 refrained 4
# 73 not-logged-in 5
# 73 excused 24
# 73 no 0
# majority for topic  73  voted for  yes
# 74 yes 170
# 74 refrained 1
# 74 not-logged-in 5
# 74 excused 24
# 74 no 0
# majority for topic  74  voted for  yes
# 75 yes 154
# 75 refrained 14
# 75 not-logged-in 4
# 75 excused 24
# 75 no 4
# majority for topic  75  voted for  yes
# 76 yes 170
# 76 refrained 2
# 76 not-logged-in 4
# 76 excused 24
# 76 no 0
# majority for topic  76  voted for  yes
# 77 yes 167
# 77 refrained 5
# 77 not-logged-in 4
# 77 excused 24
# 77 no 0
# majority for topic  77  voted for  yes
# 78 yes 15
# 78 refrained 154
# 78 not-logged-in 5
# 78 excused 24
# 78 no 2
# majority for topic  78  voted for  refrained
# 79 yes 95
# 79 refrained 18
# 79 not-logged-in 5
# 79 excused 24
# 79 no 58
# majority for topic  79  voted for  yes
# 80 yes 171
# 80 refrained 1
# 80 not-logged-in 4
# 80 excused 24
# 80 no 0
# majority for topic  80  voted for  yes
# 81 yes 170
# 81 refrained 2
# 81 not-logged-in 4
# 81 excused 24
# 81 no 0
# majority for topic  81  voted for  yes
# 82 yes 158
# 82 refrained 13
# 82 not-logged-in 3
# 82 excused 24
# 82 no 2
# majority for topic  82  voted for  yes
# 83 yes 168
# 83 refrained 4
# 83 not-logged-in 3
# 83 excused 24
# 83 no 1
# majority for topic  83  voted for  yes
# 84 yes 169
# 84 refrained 3
# 84 not-logged-in 3
# 84 excused 24
# 84 no 1
# majority for topic  84  voted for  yes
# 85 yes 152
# 85 refrained 16
# 85 not-logged-in 5
# 85 excused 23
# 85 no 4
# majority for topic  85  voted for  yes
# 86 yes 165
# 86 refrained 9
# 86 not-logged-in 4
# 86 excused 22
# 86 no 0
# majority for topic  86  voted for  yes
# 87 yes 158
# 87 refrained 15
# 87 not-logged-in 5
# 87 excused 22
# 87 no 0
# majority for topic  87  voted for  yes
# 88 yes 165
# 88 refrained 7
# 88 not-logged-in 5
# 88 excused 22
# 88 no 1
# majority for topic  88  voted for  yes
# 89 yes 170
# 89 refrained 4
# 89 not-logged-in 4
# 89 excused 22
# 89 no 0
# majority for topic  89  voted for  yes
# 90 yes 131
# 90 refrained 3
# 90 not-logged-in 54
# 90 excused 12
# 90 no 0
# majority for topic  90  voted for  yes
# 91 yes 145
# 91 refrained 10
# 91 not-logged-in 22
# 91 excused 12
# 91 no 11
# majority for topic  91  voted for  yes
# 92 yes 8
# 92 refrained 137
# 92 not-logged-in 11
# 92 excused 10
# 92 no 34
# majority for topic  92  voted for  refrained
# 93 yes 9
# 93 refrained 65
# 93 not-logged-in 9
# 93 excused 10
# 93 no 107
# majority for topic  93  voted for  no
# 94 yes 116
# 94 refrained 37
# 94 not-logged-in 5
# 94 excused 10
# 94 no 32
# majority for topic  94  voted for  yes
# 95 yes 167
# 95 refrained 16
# 95 not-logged-in 5
# 95 excused 10
# 95 no 2
# majority for topic  95  voted for  yes
# 96 yes 134
# 96 refrained 42
# 96 not-logged-in 11
# 96 excused 12
# 96 no 1
# majority for topic  96  voted for  yes
# 97 yes 155
# 97 refrained 7
# 97 not-logged-in 25
# 97 excused 13
# 97 no 0
# majority for topic  97  voted for  yes
# 98 yes 76
# 98 refrained 2
# 98 not-logged-in 28
# 98 excused 13
# 98 no 81
# majority for topic  98  voted for  no
# 99 yes 76
# 99 refrained 2
# 99 not-logged-in 27
# 99 excused 13
# 99 no 82
# majority for topic  99  voted for  no
# 100 yes 87
# 100 refrained 71
# 100 not-logged-in 27
# 100 excused 13
# 100 no 2
# majority for topic  100  voted for  yes
# 101 yes 118
# 101 refrained 16
# 101 not-logged-in 29
# 101 excused 13
# 101 no 24
# majority for topic  101  voted for  yes
# 102 yes 139
# 102 refrained 11
# 102 not-logged-in 33
# 102 excused 17
# 102 no 0
# majority for topic  102  voted for  yes
# 103 yes 170
# 103 refrained 10
# 103 not-logged-in 3
# 103 excused 17
# 103 no 0
# majority for topic  103  voted for  yes
# 104 yes 70
# 104 refrained 73
# 104 not-logged-in 8
# 104 excused 17
# 104 no 32
# majority for topic  104  voted for  refrained
# 105 yes 167
# 105 refrained 13
# 105 not-logged-in 3
# 105 excused 17
# 105 no 0
# majority for topic  105  voted for  yes
# 106 yes 175
# 106 refrained 6
# 106 not-logged-in 2
# 106 excused 17
# 106 no 0
# majority for topic  106  voted for  yes
# 107 yes 176
# 107 refrained 5
# 107 not-logged-in 2
# 107 excused 17
# 107 no 0
# majority for topic  107  voted for  yes
# 108 yes 176
# 108 refrained 5
# 108 not-logged-in 2
# 108 excused 17
# 108 no 0
# majority for topic  108  voted for  yes
# 109 yes 173
# 109 refrained 7
# 109 not-logged-in 2
# 109 excused 17
# 109 no 1
# majority for topic  109  voted for  yes
# 110 yes 170
# 110 refrained 11
# 110 not-logged-in 2
# 110 excused 17
# 110 no 0
# majority for topic  110  voted for  yes
# 111 yes 169
# 111 refrained 12
# 111 not-logged-in 2
# 111 excused 17
# 111 no 0
# majority for topic  111  voted for  yes
# 112 yes 167
# 112 refrained 12
# 112 not-logged-in 2
# 112 excused 17
# 112 no 2
# majority for topic  112  voted for  yes
# 113 yes 166
# 113 refrained 14
# 113 not-logged-in 2
# 113 excused 17
# 113 no 1
# majority for topic  113  voted for  yes
# 114 yes 166
# 114 refrained 14
# 114 not-logged-in 2
# 114 excused 17
# 114 no 1
# majority for topic  114  voted for  yes
# 115 yes 164
# 115 refrained 16
# 115 not-logged-in 2
# 115 excused 17
# 115 no 1
# majority for topic  115  voted for  yes
# 116 yes 165
# 116 refrained 15
# 116 not-logged-in 2
# 116 excused 17
# 116 no 1
# majority for topic  116  voted for  yes
# 117 yes 171
# 117 refrained 10
# 117 not-logged-in 2
# 117 excused 17
# 117 no 0
# majority for topic  117  voted for  yes
# 118 yes 171
# 118 refrained 10
# 118 not-logged-in 2
# 118 excused 17
# 118 no 0
# majority for topic  118  voted for  yes
# 119 yes 169
# 119 refrained 12
# 119 not-logged-in 2
# 119 excused 17
# 119 no 0
# majority for topic  119  voted for  yes
# 120 yes 166
# 120 refrained 14
# 120 not-logged-in 2
# 120 excused 17
# 120 no 1
# majority for topic  120  voted for  yes
# 121 yes 167
# 121 refrained 14
# 121 not-logged-in 2
# 121 excused 17
# 121 no 0
# majority for topic  121  voted for  yes
# 122 yes 165
# 122 refrained 16
# 122 not-logged-in 2
# 122 excused 17
# 122 no 0
# majority for topic  122  voted for  yes
# 123 yes 108
# 123 refrained 72
# 123 not-logged-in 4
# 123 excused 16
# 123 no 0
# majority for topic  123  voted for  yes
# 124 yes 134
# 124 refrained 46
# 124 not-logged-in 4
# 124 excused 16
# 124 no 0
# majority for topic  124  voted for  yes
# 125 yes 133
# 125 refrained 45
# 125 not-logged-in 6
# 125 excused 16
# 125 no 0
# majority for topic  125  voted for  yes
# 126 yes 120
# 126 refrained 59
# 126 not-logged-in 5
# 126 excused 16
# 126 no 0
# majority for topic  126  voted for  yes
# 127 yes 114
# 127 refrained 61
# 127 not-logged-in 7
# 127 excused 17
# 127 no 1
# majority for topic  127  voted for  yes
# 128 yes 121
# 128 refrained 46
# 128 not-logged-in 5
# 128 excused 17
# 128 no 11
# majority for topic  128  voted for  yes
# 129 yes 27
# 129 refrained 43
# 129 not-logged-in 6
# 129 excused 17
# 129 no 107
# majority for topic  129  voted for  no
# 130 yes 22
# 130 refrained 15
# 130 not-logged-in 35
# 130 excused 18
# 130 no 110
# majority for topic  130  voted for  no
# 131 yes 27
# 131 refrained 13
# 131 not-logged-in 31
# 131 excused 18
# 131 no 111
# majority for topic  131  voted for  no
# 132 yes 152
# 132 refrained 2
# 132 not-logged-in 28
# 132 excused 18
# 132 no 0
# majority for topic  132  voted for  yes
# 133 yes 138
# 133 refrained 20
# 133 not-logged-in 24
# 133 excused 18
# 133 no 0
# majority for topic  133  voted for  yes
# 134 yes 153
# 134 refrained 15
# 134 not-logged-in 12
# 134 excused 19
# 134 no 1
# majority for topic  134  voted for  yes
# 135 yes 156
# 135 refrained 3
# 135 not-logged-in 32
# 135 excused 9
# 135 no 0
# majority for topic  135  voted for  yes
# 136 yes 160
# 136 refrained 1
# 136 not-logged-in 30
# 136 excused 9
# 136 no 0
# majority for topic  136  voted for  yes
# 137 yes 164
# 137 refrained 7
# 137 not-logged-in 19
# 137 excused 9
# 137 no 1
# majority for topic  137  voted for  yes
# 138 yes 171
# 138 refrained 3
# 138 not-logged-in 17
# 138 excused 9
# 138 no 0
# majority for topic  138  voted for  yes
# 139 yes 173
# 139 refrained 2
# 139 not-logged-in 16
# 139 excused 9
# 139 no 0
# majority for topic  139  voted for  yes
# 140 yes 139
# 140 refrained 2
# 140 not-logged-in 40
# 140 excused 19
# 140 no 0
# majority for topic  140  voted for  yes
# 141 yes 170
# 141 refrained 4
# 141 not-logged-in 25
# 141 excused 1
# 141 no 0
# majority for topic  141  voted for  yes
# 142 yes 72
# 142 refrained 24
# 142 not-logged-in 18
# 142 excused 0
# 142 no 86
# majority for topic  142  voted for  no
# 143 yes 152
# 143 refrained 39
# 143 not-logged-in 5
# 143 excused 1
# 143 no 3
# majority for topic  143  voted for  yes
# 144 yes 193
# 144 refrained 4
# 144 not-logged-in 3
# 144 excused 0
# 144 no 0
# majority for topic  144  voted for  yes
# 145 yes 40
# 145 refrained 69
# 145 not-logged-in 3
# 145 excused 0
# 145 no 88
# majority for topic  145  voted for  no
# 146 yes 196
# 146 refrained 1
# 146 not-logged-in 3
# 146 excused 0
# 146 no 0
# majority for topic  146  voted for  yes
# 147 yes 90
# 147 refrained 31
# 147 not-logged-in 3
# 147 excused 0
# 147 no 76
# majority for topic  147  voted for  yes
# 148 yes 40
# 148 refrained 8
# 148 not-logged-in 3
# 148 excused 0
# 148 no 149
# majority for topic  148  voted for  no
# 149 yes 195
# 149 refrained 2
# 149 not-logged-in 3
# 149 excused 0
# 149 no 0
# majority for topic  149  voted for  yes
# 150 yes 126
# 150 refrained 9
# 150 not-logged-in 3
# 150 excused 0
# 150 no 62
# majority for topic  150  voted for  yes
# 151 yes 196
# 151 refrained 1
# 151 not-logged-in 3
# 151 excused 0
# 151 no 0
# majority for topic  151  voted for  yes
# 152 yes 196
# 152 refrained 1
# 152 not-logged-in 3
# 152 excused 0
# 152 no 0
# majority for topic  152  voted for  yes
# 153 yes 136
# 153 refrained 25
# 153 not-logged-in 3
# 153 excused 0
# 153 no 36
# majority for topic  153  voted for  yes
# 154 yes 169
# 154 refrained 26
# 154 not-logged-in 3
# 154 excused 0
# 154 no 2
# majority for topic  154  voted for  yes
# 155 yes 172
# 155 refrained 25
# 155 not-logged-in 3
# 155 excused 0
# 155 no 0
# majority for topic  155  voted for  yes
# 156 yes 195
# 156 refrained 2
# 156 not-logged-in 3
# 156 excused 0
# 156 no 0
# majority for topic  156  voted for  yes
# 157 yes 195
# 157 refrained 2
# 157 not-logged-in 3
# 157 excused 0
# 157 no 0
# majority for topic  157  voted for  yes
# 158 yes 195
# 158 refrained 2
# 158 not-logged-in 3
# 158 excused 0
# 158 no 0
# majority for topic  158  voted for  yes
# 159 yes 195
# 159 refrained 2
# 159 not-logged-in 3
# 159 excused 0
# 159 no 0
# majority for topic  159  voted for  yes
# 160 yes 62
# 160 refrained 37
# 160 not-logged-in 3
# 160 excused 0
# 160 no 98
# majority for topic  160  voted for  no
# 161 yes 45
# 161 refrained 66
# 161 not-logged-in 3
# 161 excused 0
# 161 no 86
# majority for topic  161  voted for  no
# 162 yes 48
# 162 refrained 43
# 162 not-logged-in 3
# 162 excused 0
# 162 no 106
# majority for topic  162  voted for  no
# 163 yes 35
# 163 refrained 23
# 163 not-logged-in 2
# 163 excused 0
# 163 no 140
# majority for topic  163  voted for  no
# 164 yes 15
# 164 refrained 84
# 164 not-logged-in 2
# 164 excused 0
# 164 no 99
# majority for topic  164  voted for  no
# 165 yes 35
# 165 refrained 61
# 165 not-logged-in 2
# 165 excused 0
# 165 no 102
# majority for topic  165  voted for  no
# 166 yes 68
# 166 refrained 28
# 166 not-logged-in 2
# 166 excused 0
# 166 no 102
# majority for topic  166  voted for  no
# 167 yes 53
# 167 refrained 42
# 167 not-logged-in 1
# 167 excused 0
# 167 no 104
# majority for topic  167  voted for  no
# 168 yes 30
# 168 refrained 55
# 168 not-logged-in 1
# 168 excused 0
# 168 no 114
# majority for topic  168  voted for  no
# 169 yes 39
# 169 refrained 52
# 169 not-logged-in 1
# 169 excused 0
# 169 no 108
# majority for topic  169  voted for  no
# 170 yes 39
# 170 refrained 53
# 170 not-logged-in 1
# 170 excused 0
# 170 no 107
# majority for topic  170  voted for  no
# 171 yes 51
# 171 refrained 42
# 171 not-logged-in 1
# 171 excused 0
# 171 no 106
# majority for topic  171  voted for  no
# 172 yes 53
# 172 refrained 16
# 172 not-logged-in 1
# 172 excused 0
# 172 no 130
# majority for topic  172  voted for  no
# 173 yes 50
# 173 refrained 55
# 173 not-logged-in 1
# 173 excused 0
# 173 no 94
# majority for topic  173  voted for  no
# 174 yes 68
# 174 refrained 45
# 174 not-logged-in 1
# 174 excused 0
# 174 no 86
# majority for topic  174  voted for  no
# 175 yes 43
# 175 refrained 51
# 175 not-logged-in 1
# 175 excused 0
# 175 no 105
# majority for topic  175  voted for  no
# 176 yes 37
# 176 refrained 69
# 176 not-logged-in 1
# 176 excused 0
# 176 no 93
# majority for topic  176  voted for  no
# 177 yes 37
# 177 refrained 63
# 177 not-logged-in 1
# 177 excused 0
# 177 no 99
# majority for topic  177  voted for  no
# 178 yes 37
# 178 refrained 63
# 178 not-logged-in 1
# 178 excused 0
# 178 no 99
# majority for topic  178  voted for  no
# 179 yes 35
# 179 refrained 61
# 179 not-logged-in 1
# 179 excused 0
# 179 no 103
# majority for topic  179  voted for  no
# 180 yes 37
# 180 refrained 65
# 180 not-logged-in 2
# 180 excused 0
# 180 no 96
# majority for topic  180  voted for  no
# 181 yes 59
# 181 refrained 44
# 181 not-logged-in 1
# 181 excused 0
# 181 no 96
# majority for topic  181  voted for  no
# 182 yes 37
# 182 refrained 56
# 182 not-logged-in 2
# 182 excused 0
# 182 no 105
# majority for topic  182  voted for  no
# 183 yes 37
# 183 refrained 65
# 183 not-logged-in 2
# 183 excused 0
# 183 no 96
# majority for topic  183  voted for  no
# 184 yes 29
# 184 refrained 45
# 184 not-logged-in 1
# 184 excused 0
# 184 no 125
# majority for topic  184  voted for  no
# 185 yes 27
# 185 refrained 42
# 185 not-logged-in 1
# 185 excused 0
# 185 no 130
# majority for topic  185  voted for  no
# 186 yes 36
# 186 refrained 56
# 186 not-logged-in 1
# 186 excused 0
# 186 no 107
# majority for topic  186  voted for  no
# 187 yes 28
# 187 refrained 51
# 187 not-logged-in 2
# 187 excused 0
# 187 no 119
# majority for topic  187  voted for  no
# 188 yes 23
# 188 refrained 45
# 188 not-logged-in 1
# 188 excused 0
# 188 no 131
# majority for topic  188  voted for  no
# 189 yes 30
# 189 refrained 56
# 189 not-logged-in 1
# 189 excused 0
# 189 no 113
# majority for topic  189  voted for  no
# 190 yes 49
# 190 refrained 41
# 190 not-logged-in 1
# 190 excused 0
# 190 no 109
# majority for topic  190  voted for  no
# 191 yes 29
# 191 refrained 44
# 191 not-logged-in 1
# 191 excused 0
# 191 no 126
# majority for topic  191  voted for  no
# 192 yes 52
# 192 refrained 39
# 192 not-logged-in 1
# 192 excused 0
# 192 no 108
# majority for topic  192  voted for  no
# 193 yes 35
# 193 refrained 60
# 193 not-logged-in 2
# 193 excused 0
# 193 no 103
# majority for topic  193  voted for  no
# 194 yes 53
# 194 refrained 39
# 194 not-logged-in 1
# 194 excused 0
# 194 no 107
# majority for topic  194  voted for  no
# 195 yes 62
# 195 refrained 44
# 195 not-logged-in 1
# 195 excused 0
# 195 no 93
# majority for topic  195  voted for  no
# 196 yes 83
# 196 refrained 32
# 196 not-logged-in 1
# 196 excused 0
# 196 no 84
# majority for topic  196  voted for  no
# 197 yes 65
# 197 refrained 51
# 197 not-logged-in 1
# 197 excused 0
# 197 no 83
# majority for topic  197  voted for  no
# 198 yes 64
# 198 refrained 48
# 198 not-logged-in 1
# 198 excused 0
# 198 no 87
# majority for topic  198  voted for  no
# 199 yes 98
# 199 refrained 18
# 199 not-logged-in 1
# 199 excused 0
# 199 no 83
# majority for topic  199  voted for  yes
# 200 yes 103
# 200 refrained 17
# 200 not-logged-in 1
# 200 excused 0
# 200 no 79
# majority for topic  200  voted for  yes
# 201 yes 39
# 201 refrained 73
# 201 not-logged-in 1
# 201 excused 0
# 201 no 87
# majority for topic  201  voted for  no
# 202 yes 46
# 202 refrained 68
# 202 not-logged-in 1
# 202 excused 0
# 202 no 85
# majority for topic  202  voted for  no
# 203 yes 32
# 203 refrained 71
# 203 not-logged-in 1
# 203 excused 0
# 203 no 96
# majority for topic  203  voted for  no
# 204 yes 58
# 204 refrained 50
# 204 not-logged-in 1
# 204 excused 0
# 204 no 91
# majority for topic  204  voted for  no
# 205 yes 82
# 205 refrained 24
# 205 not-logged-in 1
# 205 excused 0
# 205 no 93
# majority for topic  205  voted for  no
# 206 yes 51
# 206 refrained 52
# 206 not-logged-in 1
# 206 excused 0
# 206 no 96
# majority for topic  206  voted for  no
# 207 yes 69
# 207 refrained 38
# 207 not-logged-in 1
# 207 excused 0
# 207 no 92
# majority for topic  207  voted for  no
# 208 yes 73
# 208 refrained 52
# 208 not-logged-in 1
# 208 excused 0
# 208 no 74
# majority for topic  208  voted for  no
# 209 yes 53
# 209 refrained 46
# 209 not-logged-in 1
# 209 excused 0
# 209 no 100
# majority for topic  209  voted for  no
# 210 yes 63
# 210 refrained 44
# 210 not-logged-in 2
# 210 excused 0
# 210 no 91
# majority for topic  210  voted for  no
# 211 yes 62
# 211 refrained 39
# 211 not-logged-in 1
# 211 excused 0
# 211 no 98
# majority for topic  211  voted for  no
# 212 yes 19
# 212 refrained 65
# 212 not-logged-in 1
# 212 excused 0
# 212 no 115
# majority for topic  212  voted for  no
# 213 yes 69
# 213 refrained 32
# 213 not-logged-in 1
# 213 excused 0
# 213 no 98
# majority for topic  213  voted for  no
# 214 yes 24
# 214 refrained 72
# 214 not-logged-in 1
# 214 excused 0
# 214 no 103
# majority for topic  214  voted for  no
# 215 yes 74
# 215 refrained 36
# 215 not-logged-in 1
# 215 excused 0
# 215 no 89
# majority for topic  215  voted for  no
# 216 yes 87
# 216 refrained 19
# 216 not-logged-in 1
# 216 excused 0
# 216 no 93
# majority for topic  216  voted for  no
# 217 yes 7
# 217 refrained 112
# 217 not-logged-in 1
# 217 excused 0
# 217 no 80
# majority for topic  217  voted for  refrained
# 218 yes 2
# 218 refrained 121
# 218 not-logged-in 1
# 218 excused 0
# 218 no 76
# majority for topic  218  voted for  refrained
# 219 yes 81
# 219 refrained 40
# 219 not-logged-in 1
# 219 excused 0
# 219 no 78
# majority for topic  219  voted for  yes
# 220 yes 23
# 220 refrained 28
# 220 not-logged-in 1
# 220 excused 0
# 220 no 148
# majority for topic  220  voted for  no
# 221 yes 33
# 221 refrained 18
# 221 not-logged-in 1
# 221 excused 0
# 221 no 148
# majority for topic  221  voted for  no
# 222 yes 47
# 222 refrained 30
# 222 not-logged-in 1
# 222 excused 0
# 222 no 122
# majority for topic  222  voted for  no
# 223 yes 58
# 223 refrained 46
# 223 not-logged-in 1
# 223 excused 0
# 223 no 95
# majority for topic  223  voted for  no
# 224 yes 63
# 224 refrained 54
# 224 not-logged-in 1
# 224 excused 0
# 224 no 82
# majority for topic  224  voted for  no
# 225 yes 140
# 225 refrained 28
# 225 not-logged-in 1
# 225 excused 0
# 225 no 31
# majority for topic  225  voted for  yes
# 226 yes 192
# 226 refrained 6
# 226 not-logged-in 2
# 226 excused 0
# 226 no 0
# majority for topic  226  voted for  yes
# 227 yes 190
# 227 refrained 8
# 227 not-logged-in 2
# 227 excused 0
# 227 no 0
# majority for topic  227  voted for  yes
# 228 yes 96
# 228 refrained 77
# 228 not-logged-in 2
# 228 excused 0
# 228 no 25
# majority for topic  228  voted for  yes
# 229 yes 174
# 229 refrained 24
# 229 not-logged-in 2
# 229 excused 0
# 229 no 0
# majority for topic  229  voted for  yes
# 230 yes 122
# 230 refrained 55
# 230 not-logged-in 4
# 230 excused 0
# 230 no 19
# majority for topic  230  voted for  yes
# 231 yes 127
# 231 refrained 48
# 231 not-logged-in 10
# 231 excused 0
# 231 no 15
# majority for topic  231  voted for  yes
# 232 yes 72
# 232 refrained 18
# 232 not-logged-in 44
# 232 excused 0
# 232 no 66
# majority for topic  232  voted for  yes
# 233 yes 128
# 233 refrained 19
# 233 not-logged-in 42
# 233 excused 0
# 233 no 11
# majority for topic  233  voted for  yes
# 234 yes 130
# 234 refrained 15
# 234 not-logged-in 40
# 234 excused 0
# 234 no 15
# majority for topic  234  voted for  yes
# 235 yes 111
# 235 refrained 38
# 235 not-logged-in 36
# 235 excused 0
# 235 no 15
# majority for topic  235  voted for  yes
# 236 yes 150
# 236 refrained 10
# 236 not-logged-in 36
# 236 excused 0
# 236 no 4
# majority for topic  236  voted for  yes
# 237 yes 131
# 237 refrained 8
# 237 not-logged-in 36
# 237 excused 0
# 237 no 25
# majority for topic  237  voted for  yes
# 238 yes 162
# 238 refrained 2
# 238 not-logged-in 35
# 238 excused 1
# 238 no 0
# majority for topic  238  voted for  yes
# 239 yes 65
# 239 refrained 13
# 239 not-logged-in 6
# 239 excused 1
# 239 no 115
# majority for topic  239  voted for  no
# 240 yes 167
# 240 refrained 9
# 240 not-logged-in 6
# 240 excused 1
# 240 no 17
# majority for topic  240  voted for  yes
# 241 yes 54
# 241 refrained 29
# 241 not-logged-in 55
# 241 excused 2
# 241 no 60
# majority for topic  241  voted for  no
# 242 yes 63
# 242 refrained 28
# 242 not-logged-in 17
# 242 excused 2
# 242 no 90
# majority for topic  242  voted for  no
# 243 yes 150
# 243 refrained 6
# 243 not-logged-in 32
# 243 excused 2
# 243 no 10
# majority for topic  243  voted for  yes
# 244 yes 58
# 244 refrained 6
# 244 not-logged-in 13
# 244 excused 7
# 244 no 116
# majority for topic  244  voted for  no
# 245 yes 78
# 245 refrained 0
# 245 not-logged-in 0
# 245 excused 5
# 245 no 117
# majority for topic  245  voted for  no
# 246 yes 139
# 246 refrained 5
# 246 not-logged-in 44
# 246 excused 12
# 246 no 0
# majority for topic  246  voted for  yes
# 247 yes 178
# 247 refrained 10
# 247 not-logged-in 2
# 247 excused 10
# 247 no 0
# majority for topic  247  voted for  yes
# 248 yes 187
# 248 refrained 1
# 248 not-logged-in 2
# 248 excused 10
# 248 no 0
# majority for topic  248  voted for  yes
# 249 yes 74
# 249 refrained 10
# 249 not-logged-in 3
# 249 excused 10
# 249 no 103
# majority for topic  249  voted for  no
# 250 yes 120
# 250 refrained 64
# 250 not-logged-in 2
# 250 excused 10
# 250 no 4
# majority for topic  250  voted for  yes
# 251 yes 79
# 251 refrained 25
# 251 not-logged-in 3
# 251 excused 10
# 251 no 83
# majority for topic  251  voted for  no
# 252 yes 182
# 252 refrained 6
# 252 not-logged-in 2
# 252 excused 10
# 252 no 0
# majority for topic  252  voted for  yes
# 253 yes 182
# 253 refrained 5
# 253 not-logged-in 3
# 253 excused 10
# 253 no 0
# majority for topic  253  voted for  yes
# 254 yes 184
# 254 refrained 3
# 254 not-logged-in 3
# 254 excused 10
# 254 no 0
# majority for topic  254  voted for  yes
# 255 yes 45
# 255 refrained 125
# 255 not-logged-in 3
# 255 excused 10
# 255 no 17
# majority for topic  255  voted for  refrained
# 256 yes 186
# 256 refrained 1
# 256 not-logged-in 3
# 256 excused 10
# 256 no 0
# majority for topic  256  voted for  yes
# 257 yes 183
# 257 refrained 4
# 257 not-logged-in 3
# 257 excused 10
# 257 no 0
# majority for topic  257  voted for  yes
# 258 yes 146
# 258 refrained 38
# 258 not-logged-in 8
# 258 excused 8
# 258 no 0
# majority for topic  258  voted for  yes
# 259 yes 128
# 259 refrained 55
# 259 not-logged-in 8
# 259 excused 8
# 259 no 1
# majority for topic  259  voted for  yes
# 260 yes 163
# 260 refrained 2
# 260 not-logged-in 15
# 260 excused 20
# 260 no 0
# majority for topic  260  voted for  yes
# 261 yes 36
# 261 refrained 99
# 261 not-logged-in 15
# 261 excused 20
# 261 no 30
# majority for topic  261  voted for  refrained
# 262 yes 120
# 262 refrained 4
# 262 not-logged-in 35
# 262 excused 41
# 262 no 0
# majority for topic  262  voted for  yes
# 263 yes 123
# 263 refrained 1
# 263 not-logged-in 35
# 263 excused 41
# 263 no 0
# majority for topic  263  voted for  yes
# 264 yes 140
# 264 refrained 0
# 264 not-logged-in 22
# 264 excused 38
# 264 no 0
# majority for topic  264  voted for  yes
# 265 yes 119
# 265 refrained 22
# 265 not-logged-in 19
# 265 excused 40
# 265 no 0
# majority for topic  265  voted for  yes
# 266 yes 92
# 266 refrained 16
# 266 not-logged-in 42
# 266 excused 41
# 266 no 9
# majority for topic  266  voted for  yes
# 267 yes 56
# 267 refrained 21
# 267 not-logged-in 41
# 267 excused 41
# 267 no 41
# majority for topic  267  voted for  yes
# 268 yes 56
# 268 refrained 13
# 268 not-logged-in 41
# 268 excused 41
# 268 no 49
# majority for topic  268  voted for  yes
# 269 yes 107
# 269 refrained 12
# 269 not-logged-in 40
# 269 excused 41
# 269 no 0
# majority for topic  269  voted for  yes
# 270 yes 54
# 270 refrained 6
# 270 not-logged-in 42
# 270 excused 39
# 270 no 59
# majority for topic  270  voted for  no
# 271 yes 56
# 271 refrained 14
# 271 not-logged-in 41
# 271 excused 39
# 271 no 50
# majority for topic  271  voted for  yes
# 272 yes 159
# 272 refrained 4
# 272 not-logged-in 21
# 272 excused 16
# 272 no 0
# majority for topic  272  voted for  yes
# 273 yes 165
# 273 refrained 2
# 273 not-logged-in 17
# 273 excused 16
# 273 no 0
# majority for topic  273  voted for  yes
# 274 yes 111
# 274 refrained 0
# 274 not-logged-in 1
# 274 excused 19
# 274 no 69
# majority for topic  274  voted for  yes
# 275 yes 111
# 275 refrained 0
# 275 not-logged-in 1
# 275 excused 19
# 275 no 69
# majority for topic  275  voted for  yes
# 276 yes 163
# 276 refrained 4
# 276 not-logged-in 15
# 276 excused 18
# 276 no 0
# majority for topic  276  voted for  yes
# 277 yes 170
# 277 refrained 1
# 277 not-logged-in 11
# 277 excused 18
# 277 no 0
# majority for topic  277  voted for  yes
# 278 yes 172
# 278 refrained 1
# 278 not-logged-in 9
# 278 excused 18
# 278 no 0
# majority for topic  278  voted for  yes
# 279 yes 156
# 279 refrained 21
# 279 not-logged-in 5
# 279 excused 18
# 279 no 0
# majority for topic  279  voted for  yes
# 280 yes 162
# 280 refrained 16
# 280 not-logged-in 4
# 280 excused 18
# 280 no 0
# majority for topic  280  voted for  yes
# 281 yes 135
# 281 refrained 42
# 281 not-logged-in 5
# 281 excused 18
# 281 no 0
# majority for topic  281  voted for  yes
# 282 yes 143
# 282 refrained 33
# 282 not-logged-in 6
# 282 excused 18
# 282 no 0
# majority for topic  282  voted for  yes
# 283 yes 116
# 283 refrained 52
# 283 not-logged-in 6
# 283 excused 18
# 283 no 8
# majority for topic  283  voted for  yes
# 284 yes 76
# 284 refrained 60
# 284 not-logged-in 6
# 284 excused 18
# 284 no 40
# majority for topic  284  voted for  yes
# 285 yes 79
# 285 refrained 36
# 285 not-logged-in 5
# 285 excused 18
# 285 no 62
# majority for topic  285  voted for  yes
# 286 yes 143
# 286 refrained 29
# 286 not-logged-in 5
# 286 excused 18
# 286 no 5
# majority for topic  286  voted for  yes
# 287 yes 149
# 287 refrained 28
# 287 not-logged-in 5
# 287 excused 18
# 287 no 0
# majority for topic  287  voted for  yes
# 288 yes 90
# 288 refrained 21
# 288 not-logged-in 14
# 288 excused 21
# 288 no 54
# majority for topic  288  voted for  yes
# 289 yes 102
# 289 refrained 6
# 289 not-logged-in 14
# 289 excused 21
# 289 no 57
# majority for topic  289  voted for  yes
# 290 yes 124
# 290 refrained 39
# 290 not-logged-in 13
# 290 excused 24
# 290 no 0
# majority for topic  290  voted for  yes
# 291 yes 102
# 291 refrained 37
# 291 not-logged-in 11
# 291 excused 23
# 291 no 27
# majority for topic  291  voted for  yes
# 292 yes 83
# 292 refrained 6
# 292 not-logged-in 21
# 292 excused 26
# 292 no 64
# majority for topic  292  voted for  yes
# 293 yes 110
# 293 refrained 10
# 293 not-logged-in 12
# 293 excused 29
# 293 no 39
# majority for topic  293  voted for  yes
# 294 yes 127
# 294 refrained 2
# 294 not-logged-in 26
# 294 excused 29
# 294 no 16
# majority for topic  294  voted for  yes
# 295 yes 128
# 295 refrained 2
# 295 not-logged-in 25
# 295 excused 29
# 295 no 16
# majority for topic  295  voted for  yes
# 296 yes 130
# 296 refrained 25
# 296 not-logged-in 17
# 296 excused 28
# 296 no 0
# majority for topic  296  voted for  yes
# 297 yes 147
# 297 refrained 12
# 297 not-logged-in 13
# 297 excused 28
# 297 no 0
# majority for topic  297  voted for  yes
# 298 yes 85
# 298 refrained 26
# 298 not-logged-in 13
# 298 excused 28
# 298 no 48
# majority for topic  298  voted for  yes
# 299 yes 148
# 299 refrained 14
# 299 not-logged-in 9
# 299 excused 29
# 299 no 0
# majority for topic  299  voted for  yes
# 300 yes 152
# 300 refrained 10
# 300 not-logged-in 9
# 300 excused 29
# 300 no 0
# majority for topic  300  voted for  yes
# 301 yes 151
# 301 refrained 9
# 301 not-logged-in 11
# 301 excused 29
# 301 no 0
# majority for topic  301  voted for  yes
# 302 yes 154
# 302 refrained 7
# 302 not-logged-in 10
# 302 excused 29
# 302 no 0
# majority for topic  302  voted for  yes
# 303 yes 81
# 303 refrained 28
# 303 not-logged-in 22
# 303 excused 30
# 303 no 39
# majority for topic  303  voted for  yes
# 304 yes 49
# 304 refrained 10
# 304 not-logged-in 19
# 304 excused 34
# 304 no 88
# majority for topic  304  voted for  no
# 305 yes 45
# 305 refrained 27
# 305 not-logged-in 18
# 305 excused 34
# 305 no 76
# majority for topic  305  voted for  no
# 306 yes 16
# 306 refrained 42
# 306 not-logged-in 26
# 306 excused 33
# 306 no 83
# majority for topic  306  voted for  no
# 307 yes 18
# 307 refrained 27
# 307 not-logged-in 23
# 307 excused 34
# 307 no 98
# majority for topic  307  voted for  no
# 308 yes 125
# 308 refrained 0
# 308 not-logged-in 40
# 308 excused 35
# 308 no 0
# majority for topic  308  voted for  yes
# 309 yes 124
# 309 refrained 0
# 309 not-logged-in 39
# 309 excused 37
# 309 no 0
# majority for topic  309  voted for  yes
# 310 yes 125
# 310 refrained 5
# 310 not-logged-in 33
# 310 excused 37
# 310 no 0
# majority for topic  310  voted for  yes
# 311 yes 113
# 311 refrained 15
# 311 not-logged-in 31
# 311 excused 37
# 311 no 4
# majority for topic  311  voted for  yes
# 312 yes 116
# 312 refrained 16
# 312 not-logged-in 31
# 312 excused 37
# 312 no 0
# majority for topic  312  voted for  yes
# 313 yes 106
# 313 refrained 4
# 313 not-logged-in 41
# 313 excused 49
# 313 no 0
# majority for topic  313  voted for  yes
# 314 yes 95
# 314 refrained 4
# 314 not-logged-in 40
# 314 excused 48
# 314 no 13
# majority for topic  314  voted for  yes
# 315 yes 110
# 315 refrained 9
# 315 not-logged-in 33
# 315 excused 48
# 315 no 0
# majority for topic  315  voted for  yes
# 316 yes 113
# 316 refrained 8
# 316 not-logged-in 31
# 316 excused 48
# 316 no 0
# majority for topic  316  voted for  yes
# 317 yes 113
# 317 refrained 10
# 317 not-logged-in 29
# 317 excused 48
# 317 no 0
# majority for topic  317  voted for  yes
# 318 yes 115
# 318 refrained 13
# 318 not-logged-in 23
# 318 excused 49
# 318 no 0
# majority for topic  318  voted for  yes
# 319 yes 81
# 319 refrained 22
# 319 not-logged-in 23
# 319 excused 49
# 319 no 25
# majority for topic  319  voted for  yes
# 320 yes 65
# 320 refrained 17
# 320 not-logged-in 23
# 320 excused 49
# 320 no 46
# majority for topic  320  voted for  yes
# 321 yes 107
# 321 refrained 24
# 321 not-logged-in 20
# 321 excused 49
# 321 no 0
# majority for topic  321  voted for  yes
# 322 yes 116
# 322 refrained 17
# 322 not-logged-in 19
# 322 excused 48
# 322 no 0
# majority for topic  322  voted for  yes
# 323 yes 58
# 323 refrained 20
# 323 not-logged-in 19
# 323 excused 48
# 323 no 55
# majority for topic  323  voted for  yes
# 324 yes 112
# 324 refrained 22
# 324 not-logged-in 18
# 324 excused 48
# 324 no 0
# majority for topic  324  voted for  yes
# 325 yes 57
# 325 refrained 20
# 325 not-logged-in 17
# 325 excused 48
# 325 no 58
# majority for topic  325  voted for  no
# 326 yes 123
# 326 refrained 16
# 326 not-logged-in 13
# 326 excused 48
# 326 no 0
# majority for topic  326  voted for  yes
# 327 yes 112
# 327 refrained 26
# 327 not-logged-in 14
# 327 excused 48
# 327 no 0
# majority for topic  327  voted for  yes
# 328 yes 38
# 328 refrained 7
# 328 not-logged-in 23
# 328 excused 49
# 328 no 83
# majority for topic  328  voted for  no
# 329 yes 135
# 329 refrained 1
# 329 not-logged-in 12
# 329 excused 52
# 329 no 0
# majority for topic  329  voted for  yes
# 330 yes 136
# 330 refrained 1
# 330 not-logged-in 11
# 330 excused 52
# 330 no 0
# majority for topic  330  voted for  yes
# 331 yes 48
# 331 refrained 7
# 331 not-logged-in 12
# 331 excused 52
# 331 no 81
# majority for topic  331  voted for  no
# 332 yes 14
# 332 refrained 17
# 332 not-logged-in 11
# 332 excused 52
# 332 no 106
# majority for topic  332  voted for  no
# 333 yes 131
# 333 refrained 6
# 333 not-logged-in 11
# 333 excused 52
# 333 no 0
# majority for topic  333  voted for  yes
# 334 yes 120
# 334 refrained 12
# 334 not-logged-in 45
# 334 excused 23
# 334 no 0
# majority for topic  334  voted for  yes
# 335 yes 143
# 335 refrained 27
# 335 not-logged-in 7
# 335 excused 23
# 335 no 0
# majority for topic  335  voted for  yes
# 336 yes 70
# 336 refrained 29
# 336 not-logged-in 8
# 336 excused 23
# 336 no 70
# majority for topic  336  voted for  yes
# 337 yes 167
# 337 refrained 5
# 337 not-logged-in 5
# 337 excused 23
# 337 no 0
# majority for topic  337  voted for  yes
# 338 yes 65
# 338 refrained 39
# 338 not-logged-in 5
# 338 excused 23
# 338 no 68
# majority for topic  338  voted for  no
# 339 yes 109
# 339 refrained 17
# 339 not-logged-in 14
# 339 excused 23
# 339 no 37
# majority for topic  339  voted for  yes
# 340 yes 104
# 340 refrained 22
# 340 not-logged-in 28
# 340 excused 22
# 340 no 24
# majority for topic  340  voted for  yes
# 341 yes 56
# 341 refrained 34
# 341 not-logged-in 31
# 341 excused 22
# 341 no 57
# majority for topic  341  voted for  no
# 342 yes 135
# 342 refrained 1
# 342 not-logged-in 38
# 342 excused 26
# 342 no 0
# majority for topic  342  voted for  yes
# 343 yes 98
# 343 refrained 25
# 343 not-logged-in 33
# 343 excused 26
# 343 no 18
# majority for topic  343  voted for  yes
# 344 yes 145
# 344 refrained 12
# 344 not-logged-in 16
# 344 excused 26
# 344 no 1
# majority for topic  344  voted for  yes
# 345 yes 149
# 345 refrained 10
# 345 not-logged-in 15
# 345 excused 26
# 345 no 0
# majority for topic  345  voted for  yes
# 346 yes 55
# 346 refrained 10
# 346 not-logged-in 12
# 346 excused 26
# 346 no 97
# majority for topic  346  voted for  no
# 347 yes 51
# 347 refrained 15
# 347 not-logged-in 10
# 347 excused 26
# 347 no 98
# majority for topic  347  voted for  no
# 348 yes 65
# 348 refrained 10
# 348 not-logged-in 9
# 348 excused 26
# 348 no 90
# majority for topic  348  voted for  no
# 349 yes 140
# 349 refrained 16
# 349 not-logged-in 9
# 349 excused 26
# 349 no 9
# majority for topic  349  voted for  yes
# 350 yes 146
# 350 refrained 18
# 350 not-logged-in 7
# 350 excused 26
# 350 no 3
# majority for topic  350  voted for  yes
# 351 yes 114
# 351 refrained 49
# 351 not-logged-in 11
# 351 excused 26
# 351 no 0
# majority for topic  351  voted for  yes
# 352 yes 154
# 352 refrained 18
# 352 not-logged-in 6
# 352 excused 22
# 352 no 0
# majority for topic  352  voted for  yes
# 353 yes 155
# 353 refrained 17
# 353 not-logged-in 6
# 353 excused 22
# 353 no 0
# majority for topic  353  voted for  yes
# 354 yes 145
# 354 refrained 25
# 354 not-logged-in 7
# 354 excused 22
# 354 no 1
# majority for topic  354  voted for  yes
# 355 yes 147
# 355 refrained 22
# 355 not-logged-in 7
# 355 excused 22
# 355 no 2
# majority for topic  355  voted for  yes
# 356 yes 93
# 356 refrained 4
# 356 not-logged-in 19
# 356 excused 25
# 356 no 59
# majority for topic  356  voted for  yes
# 357 yes 109
# 357 refrained 53
# 357 not-logged-in 12
# 357 excused 26
# 357 no 0
# majority for topic  357  voted for  yes
# 358 yes 106
# 358 refrained 9
# 358 not-logged-in 16
# 358 excused 27
# 358 no 42
# majority for topic  358  voted for  yes
# 359 yes 152
# 359 refrained 4
# 359 not-logged-in 16
# 359 excused 27
# 359 no 1
# majority for topic  359  voted for  yes
# 360 yes 155
# 360 refrained 2
# 360 not-logged-in 16
# 360 excused 27
# 360 no 0
# majority for topic  360  voted for  yes
# 361 yes 123
# 361 refrained 33
# 361 not-logged-in 16
# 361 excused 27
# 361 no 1
# majority for topic  361  voted for  yes
# 362 yes 0
# 362 refrained 157
# 362 not-logged-in 14
# 362 excused 27
# 362 no 2
# majority for topic  362  voted for  refrained
# 363 yes 34
# 363 refrained 49
# 363 not-logged-in 33
# 363 excused 27
# 363 no 57
# majority for topic  363  voted for  no
# 364 yes 96
# 364 refrained 9
# 364 not-logged-in 26
# 364 excused 27
# 364 no 42
# majority for topic  364  voted for  yes
# 365 yes 64
# 365 refrained 39
# 365 not-logged-in 25
# 365 excused 28
# 365 no 44
# majority for topic  365  voted for  yes
# 366 yes 115
# 366 refrained 23
# 366 not-logged-in 21
# 366 excused 28
# 366 no 13
# majority for topic  366  voted for  yes
# 367 yes 94
# 367 refrained 7
# 367 not-logged-in 21
# 367 excused 28
# 367 no 50
# majority for topic  367  voted for  yes
# 368 yes 23
# 368 refrained 51
# 368 not-logged-in 50
# 368 excused 47
# 368 no 29
# majority for topic  368  voted for  refrained
# 369 yes 100
# 369 refrained 10
# 369 not-logged-in 43
# 369 excused 47
# 369 no 0
# majority for topic  369  voted for  yes
# 370 yes 96
# 370 refrained 14
# 370 not-logged-in 43
# 370 excused 47
# 370 no 0
# majority for topic  370  voted for  yes
# 371 yes 79
# 371 refrained 38
# 371 not-logged-in 28
# 371 excused 42
# 371 no 13
# majority for topic  371  voted for  yes
# 372 yes 17
# 372 refrained 57
# 372 not-logged-in 26
# 372 excused 42
# 372 no 58
# majority for topic  372  voted for  no
# 373 yes 29
# 373 refrained 8
# 373 not-logged-in 28
# 373 excused 42
# 373 no 93
# majority for topic  373  voted for  no
# 374 yes 128
# 374 refrained 3
# 374 not-logged-in 27
# 374 excused 42
# 374 no 0
# majority for topic  374  voted for  yes
# 375 yes 146
# 375 refrained 12
# 375 not-logged-in 4
# 375 excused 37
# 375 no 1
# majority for topic  375  voted for  yes
# 376 yes 154
# 376 refrained 5
# 376 not-logged-in 4
# 376 excused 37
# 376 no 0
# majority for topic  376  voted for  yes
# 377 yes 133
# 377 refrained 2
# 377 not-logged-in 24
# 377 excused 40
# 377 no 1
# majority for topic  377  voted for  yes
# 378 yes 135
# 378 refrained 15
# 378 not-logged-in 10
# 378 excused 40
# 378 no 0
# majority for topic  378  voted for  yes
# 379 yes 138
# 379 refrained 12
# 379 not-logged-in 10
# 379 excused 40
# 379 no 0
# majority for topic  379  voted for  yes
# 380 yes 121
# 380 refrained 10
# 380 not-logged-in 29
# 380 excused 40
# 380 no 0
# majority for topic  380  voted for  yes
# 381 yes 126
# 381 refrained 7
# 381 not-logged-in 27
# 381 excused 40
# 381 no 0
# majority for topic  381  voted for  yes
# 382 yes 94
# 382 refrained 39
# 382 not-logged-in 27
# 382 excused 40
# 382 no 0
# majority for topic  382  voted for  yes
# 383 yes 126
# 383 refrained 9
# 383 not-logged-in 25
# 383 excused 40
# 383 no 0
# majority for topic  383  voted for  yes
# 384 yes 175
# 384 refrained 9
# 384 not-logged-in 1
# 384 excused 15
# 384 no 0
# majority for topic  384  voted for  yes
# 385 yes 14
# 385 refrained 168
# 385 not-logged-in 1
# 385 excused 15
# 385 no 2
# majority for topic  385  voted for  refrained
# 386 yes 179
# 386 refrained 5
# 386 not-logged-in 1
# 386 excused 15
# 386 no 0
# majority for topic  386  voted for  yes
# 387 yes 50
# 387 refrained 25
# 387 not-logged-in 17
# 387 excused 22
# 387 no 86
# majority for topic  387  voted for  no
# 388 yes 50
# 388 refrained 24
# 388 not-logged-in 17
# 388 excused 22
# 388 no 87
# majority for topic  388  voted for  no
# 389 yes 153
# 389 refrained 5
# 389 not-logged-in 16
# 389 excused 22
# 389 no 4
# majority for topic  389  voted for  yes
# 390 yes 156
# 390 refrained 3
# 390 not-logged-in 15
# 390 excused 22
# 390 no 4
# majority for topic  390  voted for  yes
# 391 yes 118
# 391 refrained 42
# 391 not-logged-in 16
# 391 excused 23
# 391 no 1
# majority for topic  391  voted for  yes
# 392 yes 139
# 392 refrained 23
# 392 not-logged-in 15
# 392 excused 23
# 392 no 0
# majority for topic  392  voted for  yes
# 393 yes 90
# 393 refrained 47
# 393 not-logged-in 15
# 393 excused 23
# 393 no 25
# majority for topic  393  voted for  yes
# 394 yes 142
# 394 refrained 6
# 394 not-logged-in 26
# 394 excused 26
# 394 no 0
# majority for topic  394  voted for  yes
# 395 yes 77
# 395 refrained 7
# 395 not-logged-in 18
# 395 excused 21
# 395 no 77
# majority for topic  395  voted for  yes
# 396 yes 158
# 396 refrained 3
# 396 not-logged-in 18
# 396 excused 21
# 396 no 0
# majority for topic  396  voted for  yes
# 397 yes 71
# 397 refrained 16
# 397 not-logged-in 31
# 397 excused 20
# 397 no 62
# majority for topic  397  voted for  yes
# 398 yes 145
# 398 refrained 4
# 398 not-logged-in 31
# 398 excused 20
# 398 no 0
# majority for topic  398  voted for  yes
# 399 yes 45
# 399 refrained 8
# 399 not-logged-in 36
# 399 excused 20
# 399 no 91
# majority for topic  399  voted for  no
# 400 yes 39
# 400 refrained 21
# 400 not-logged-in 24
# 400 excused 17
# 400 no 99
# majority for topic  400  voted for  no
# 401 yes 30
# 401 refrained 52
# 401 not-logged-in 24
# 401 excused 17
# 401 no 77
# majority for topic  401  voted for  no
# 402 yes 83
# 402 refrained 43
# 402 not-logged-in 23
# 402 excused 17
# 402 no 34
# majority for topic  402  voted for  yes
# 403 yes 156
# 403 refrained 5
# 403 not-logged-in 22
# 403 excused 17
# 403 no 0
# majority for topic  403  voted for  yes
# 404 yes 94
# 404 refrained 47
# 404 not-logged-in 21
# 404 excused 17
# 404 no 21
# majority for topic  404  voted for  yes
# 405 yes 115
# 405 refrained 32
# 405 not-logged-in 21
# 405 excused 17
# 405 no 15
# majority for topic  405  voted for  yes
# 406 yes 143
# 406 refrained 14
# 406 not-logged-in 21
# 406 excused 17
# 406 no 5
# majority for topic  406  voted for  yes
# 407 yes 142
# 407 refrained 14
# 407 not-logged-in 21
# 407 excused 17
# 407 no 6
# majority for topic  407  voted for  yes
# 408 yes 102
# 408 refrained 57
# 408 not-logged-in 20
# 408 excused 16
# 408 no 5
# majority for topic  408  voted for  yes
# 409 yes 64
# 409 refrained 81
# 409 not-logged-in 6
# 409 excused 24
# 409 no 25
# majority for topic  409  voted for  refrained
# 410 yes 1
# 410 refrained 169
# 410 not-logged-in 6
# 410 excused 24
# 410 no 0
# majority for topic  410  voted for  refrained
# 411 yes 156
# 411 refrained 8
# 411 not-logged-in 11
# 411 excused 24
# 411 no 1
# majority for topic  411  voted for  yes
# 412 yes 71
# 412 refrained 88
# 412 not-logged-in 8
# 412 excused 24
# 412 no 9
# majority for topic  412  voted for  refrained
# 413 yes 168
# 413 refrained 1
# 413 not-logged-in 7
# 413 excused 24
# 413 no 0
# majority for topic  413  voted for  yes
# 414 yes 62
# 414 refrained 108
# 414 not-logged-in 5
# 414 excused 24
# 414 no 1
# majority for topic  414  voted for  refrained
# 415 yes 66
# 415 refrained 91
# 415 not-logged-in 6
# 415 excused 24
# 415 no 13
# majority for topic  415  voted for  refrained
# 416 yes 105
# 416 refrained 33
# 416 not-logged-in 5
# 416 excused 24
# 416 no 33
# majority for topic  416  voted for  yes
# 417 yes 142
# 417 refrained 21
# 417 not-logged-in 6
# 417 excused 24
# 417 no 7
# majority for topic  417  voted for  yes
# 418 yes 157
# 418 refrained 17
# 418 not-logged-in 3
# 418 excused 23
# 418 no 0
# majority for topic  418  voted for  yes
# 419 yes 86
# 419 refrained 3
# 419 not-logged-in 19
# 419 excused 21
# 419 no 71
# majority for topic  419  voted for  yes
# 420 yes 145
# 420 refrained 21
# 420 not-logged-in 13
# 420 excused 21
# 420 no 0
# majority for topic  420  voted for  yes
# 421 yes 146
# 421 refrained 21
# 421 not-logged-in 12
# 421 excused 21
# 421 no 0
# majority for topic  421  voted for  yes
# 422 yes 31
# 422 refrained 37
# 422 not-logged-in 17
# 422 excused 21
# 422 no 94
# majority for topic  422  voted for  no
# 423 yes 161
# 423 refrained 1
# 423 not-logged-in 17
# 423 excused 21
# 423 no 0
# majority for topic  423  voted for  yes
# 424 yes 95
# 424 refrained 27
# 424 not-logged-in 17
# 424 excused 21
# 424 no 40
# majority for topic  424  voted for  yes
# 425 yes 144
# 425 refrained 21
# 425 not-logged-in 14
# 425 excused 21
# 425 no 0
# majority for topic  425  voted for  yes
# 426 yes 144
# 426 refrained 24
# 426 not-logged-in 11
# 426 excused 21
# 426 no 0
# majority for topic  426  voted for  yes
# 427 yes 129
# 427 refrained 38
# 427 not-logged-in 8
# 427 excused 21
# 427 no 4
# majority for topic  427  voted for  yes
# 428 yes 124
# 428 refrained 48
# 428 not-logged-in 7
# 428 excused 21
# 428 no 0
# majority for topic  428  voted for  yes
# 429 yes 137
# 429 refrained 12
# 429 not-logged-in 28
# 429 excused 23
# 429 no 0
# majority for topic  429  voted for  yes
# 430 yes 24
# 430 refrained 21
# 430 not-logged-in 12
# 430 excused 25
# 430 no 118
# ...
# 4806 yes 61
# 4806 refrained 33
# 4806 not-logged-in 2
# 4806 excused 4
# 4806 no 100
# majority for topic  4806  voted for  no
# 4807 yes 81
# 4807 refrained 15
# 4807 not-logged-in 2
# 4807 excused 4
# 4807 no 98
# majority for topic  4807  voted for  no
# 4808 yes 60
# 4808 refrained 38
# 4808 not-logged-in 2
# 4808 excused 4
# 4808 no 96
# majority for topic  4808  voted for  no
# 4809 yes 62
# 4809 refrained 32
# 4809 not-logged-in 2
# 4809 excused 4
# 4809 no 100
# majority for topic  4809  voted for  no
# 4810 yes 61
# 4810 refrained 34
# 4810 not-logged-in 2
# 4810 excused 4
# 4810 no 99
# majority for topic  4810  voted for  no
# 4811 yes 62
# 4811 refrained 40
# 4811 not-logged-in 2
# 4811 excused 4
# 4811 no 92
# majority for topic  4811  voted for  no
# 4812 yes 64
# 4812 refrained 21
# 4812 not-logged-in 2
# 4812 excused 4
# 4812 no 109
# majority for topic  4812  voted for  no
# 4813 yes 62
# 4813 refrained 21
# 4813 not-logged-in 2
# 4813 excused 4
# 4813 no 111
# majority for topic  4813  voted for  no
# 4814 yes 61
# 4814 refrained 36
# 4814 not-logged-in 2
# 4814 excused 4
# 4814 no 97
# majority for topic  4814  voted for  no
# 4815 yes 40
# 4815 refrained 55
# 4815 not-logged-in 2
# 4815 excused 4
# 4815 no 99
# majority for topic  4815  voted for  no
# 4816 yes 62
# 4816 refrained 38
# 4816 not-logged-in 2
# 4816 excused 4
# 4816 no 94
# majority for topic  4816  voted for  no
# 4817 yes 61
# 4817 refrained 25
# 4817 not-logged-in 2
# 4817 excused 4
# 4817 no 108
# majority for topic  4817  voted for  no
# 4818 yes 63
# 4818 refrained 43
# 4818 not-logged-in 4
# 4818 excused 4
# 4818 no 86
# majority for topic  4818  voted for  no
# 4819 yes 62
# 4819 refrained 43
# 4819 not-logged-in 5
# 4819 excused 4
# 4819 no 86
# majority for topic  4819  voted for  no
# 4820 yes 62
# 4820 refrained 42
# 4820 not-logged-in 4
# 4820 excused 4
# 4820 no 88
# majority for topic  4820  voted for  no
# 4821 yes 57
# 4821 refrained 41
# 4821 not-logged-in 2
# 4821 excused 4
# 4821 no 96
# majority for topic  4821  voted for  no
# 4822 yes 39
# 4822 refrained 44
# 4822 not-logged-in 2
# 4822 excused 4
# 4822 no 111
# majority for topic  4822  voted for  no
# 4823 yes 61
# 4823 refrained 37
# 4823 not-logged-in 2
# 4823 excused 4
# 4823 no 96
# majority for topic  4823  voted for  no
# 4824 yes 35
# 4824 refrained 27
# 4824 not-logged-in 2
# 4824 excused 4
# 4824 no 132
# majority for topic  4824  voted for  no
# 4825 yes 17
# 4825 refrained 39
# 4825 not-logged-in 2
# 4825 excused 4
# 4825 no 138
# majority for topic  4825  voted for  no
# 4826 yes 64
# 4826 refrained 37
# 4826 not-logged-in 2
# 4826 excused 4
# 4826 no 93
# majority for topic  4826  voted for  no
# 4827 yes 119
# 4827 refrained 43
# 4827 not-logged-in 9
# 4827 excused 4
# 4827 no 25
# majority for topic  4827  voted for  yes
# 4828 yes 35
# 4828 refrained 53
# 4828 not-logged-in 8
# 4828 excused 4
# 4828 no 100
# majority for topic  4828  voted for  no
# 4829 yes 36
# 4829 refrained 50
# 4829 not-logged-in 8
# 4829 excused 4
# 4829 no 102
# majority for topic  4829  voted for  no
# 4830 yes 35
# 4830 refrained 54
# 4830 not-logged-in 8
# 4830 excused 4
# 4830 no 99
# majority for topic  4830  voted for  no
# 4831 yes 36
# 4831 refrained 54
# 4831 not-logged-in 8
# 4831 excused 4
# 4831 no 98
# majority for topic  4831  voted for  no
# 4832 yes 61
# 4832 refrained 35
# 4832 not-logged-in 8
# 4832 excused 4
# 4832 no 92
# majority for topic  4832  voted for  no
# 4833 yes 38
# 4833 refrained 52
# 4833 not-logged-in 8
# 4833 excused 4
# 4833 no 98
# majority for topic  4833  voted for  no
# 4834 yes 77
# 4834 refrained 20
# 4834 not-logged-in 8
# 4834 excused 4
# 4834 no 91
# majority for topic  4834  voted for  no
# 4835 yes 60
# 4835 refrained 42
# 4835 not-logged-in 8
# 4835 excused 4
# 4835 no 86
# majority for topic  4835  voted for  no
# 4836 yes 64
# 4836 refrained 35
# 4836 not-logged-in 7
# 4836 excused 4
# 4836 no 90
# majority for topic  4836  voted for  no
# 4837 yes 65
# 4837 refrained 34
# 4837 not-logged-in 7
# 4837 excused 4
# 4837 no 90
# majority for topic  4837  voted for  no
# 4838 yes 77
# 4838 refrained 19
# 4838 not-logged-in 7
# 4838 excused 4
# 4838 no 93
# majority for topic  4838  voted for  no
# 4839 yes 62
# 4839 refrained 27
# 4839 not-logged-in 7
# 4839 excused 4
# 4839 no 100
# majority for topic  4839  voted for  no
# 4840 yes 62
# 4840 refrained 41
# 4840 not-logged-in 6
# 4840 excused 4
# 4840 no 87
# majority for topic  4840  voted for  no
# 4841 yes 78
# 4841 refrained 22
# 4841 not-logged-in 7
# 4841 excused 4
# 4841 no 89
# majority for topic  4841  voted for  no
# 4842 yes 74
# 4842 refrained 29
# 4842 not-logged-in 6
# 4842 excused 4
# 4842 no 87
# majority for topic  4842  voted for  no
# 4843 yes 79
# 4843 refrained 19
# 4843 not-logged-in 5
# 4843 excused 4
# 4843 no 93
# majority for topic  4843  voted for  no
# 4844 yes 65
# 4844 refrained 39
# 4844 not-logged-in 7
# 4844 excused 5
# 4844 no 84
# majority for topic  4844  voted for  no
# 4845 yes 47
# 4845 refrained 31
# 4845 not-logged-in 5
# 4845 excused 4
# 4845 no 113
# majority for topic  4845  voted for  no
# 4846 yes 47
# 4846 refrained 43
# 4846 not-logged-in 5
# 4846 excused 4
# 4846 no 101
# majority for topic  4846  voted for  no
# 4847 yes 47
# 4847 refrained 51
# 4847 not-logged-in 5
# 4847 excused 4
# 4847 no 93
# majority for topic  4847  voted for  no
# 4848 yes 145
# 4848 refrained 34
# 4848 not-logged-in 6
# 4848 excused 4
# 4848 no 11
# majority for topic  4848  voted for  yes
# 4849 yes 160
# 4849 refrained 7
# 4849 not-logged-in 5
# 4849 excused 4
# 4849 no 24
# majority for topic  4849  voted for  yes
# 4850 yes 180
# 4850 refrained 9
# 4850 not-logged-in 5
# 4850 excused 4
# 4850 no 2
# majority for topic  4850  voted for  yes
# 4851 yes 40
# 4851 refrained 59
# 4851 not-logged-in 6
# 4851 excused 4
# 4851 no 91
# majority for topic  4851  voted for  no
# 4852 yes 108
# 4852 refrained 1
# 4852 not-logged-in 5
# 4852 excused 4
# 4852 no 82
# majority for topic  4852  voted for  yes
# 4853 yes 85
# 4853 refrained 29
# 4853 not-logged-in 5
# 4853 excused 4
# 4853 no 77
# majority for topic  4853  voted for  yes
# 4854 yes 82
# 4854 refrained 40
# 4854 not-logged-in 5
# 4854 excused 4
# 4854 no 69
# majority for topic  4854  voted for  yes
# 4855 yes 83
# 4855 refrained 37
# 4855 not-logged-in 4
# 4855 excused 4
# 4855 no 72
# majority for topic  4855  voted for  yes
# 4856 yes 81
# 4856 refrained 54
# 4856 not-logged-in 4
# 4856 excused 4
# 4856 no 57
# majority for topic  4856  voted for  yes
# 4857 yes 62
# 4857 refrained 50
# 4857 not-logged-in 4
# 4857 excused 4
# 4857 no 80
# majority for topic  4857  voted for  no
# 4858 yes 108
# 4858 refrained 83
# 4858 not-logged-in 4
# 4858 excused 4
# 4858 no 1
# majority for topic  4858  voted for  yes
# 4859 yes 77
# 4859 refrained 37
# 4859 not-logged-in 6
# 4859 excused 4
# 4859 no 76
# majority for topic  4859  voted for  yes
# 4860 yes 56
# 4860 refrained 55
# 4860 not-logged-in 5
# 4860 excused 4
# 4860 no 80
# majority for topic  4860  voted for  no
# 4861 yes 107
# 4861 refrained 69
# 4861 not-logged-in 6
# 4861 excused 4
# 4861 no 14
# majority for topic  4861  voted for  yes
# 4862 yes 90
# 4862 refrained 10
# 4862 not-logged-in 40
# 4862 excused 6
# 4862 no 54
# majority for topic  4862  voted for  yes
# 4863 yes 107
# 4863 refrained 48
# 4863 not-logged-in 39
# 4863 excused 6
# 4863 no 0
# majority for topic  4863  voted for  yes
# 4864 yes 88
# 4864 refrained 41
# 4864 not-logged-in 35
# 4864 excused 7
# 4864 no 29
# majority for topic  4864  voted for  yes
# 4865 yes 0
# 4865 refrained 157
# 4865 not-logged-in 36
# 4865 excused 7
# 4865 no 0
# majority for topic  4865  voted for  refrained
# 4866 yes 59
# 4866 refrained 25
# 4866 not-logged-in 46
# 4866 excused 7
# 4866 no 63
# majority for topic  4866  voted for  no
# 4867 yes 103
# 4867 refrained 36
# 4867 not-logged-in 44
# 4867 excused 7
# 4867 no 10
# majority for topic  4867  voted for  yes
# 4868 yes 97
# 4868 refrained 35
# 4868 not-logged-in 44
# 4868 excused 7
# 4868 no 17
# majority for topic  4868  voted for  yes
# 4869 yes 107
# 4869 refrained 36
# 4869 not-logged-in 46
# 4869 excused 7
# 4869 no 4
# majority for topic  4869  voted for  yes
# 4870 yes 53
# 4870 refrained 27
# 4870 not-logged-in 19
# 4870 excused 31
# 4870 no 70
# majority for topic  4870  voted for  no
# 4871 yes 97
# 4871 refrained 52
# 4871 not-logged-in 16
# 4871 excused 31
# 4871 no 4
# majority for topic  4871  voted for  yes
# 4872 yes 132
# 4872 refrained 14
# 4872 not-logged-in 1
# 4872 excused 33
# 4872 no 20
# majority for topic  4872  voted for  yes
# 4873 yes 155
# 4873 refrained 11
# 4873 not-logged-in 1
# 4873 excused 33
# 4873 no 0
# majority for topic  4873  voted for  yes
# 4874 yes 156
# 4874 refrained 10
# 4874 not-logged-in 1
# 4874 excused 33
# 4874 no 0
# majority for topic  4874  voted for  yes
# 4875 yes 26
# 4875 refrained 128
# 4875 not-logged-in 1
# 4875 excused 33
# 4875 no 12
# majority for topic  4875  voted for  refrained
# 4876 yes 139
# 4876 refrained 17
# 4876 not-logged-in 2
# 4876 excused 33
# 4876 no 9
# majority for topic  4876  voted for  yes
# 4877 yes 59
# 4877 refrained 86
# 4877 not-logged-in 2
# 4877 excused 33
# 4877 no 20
# majority for topic  4877  voted for  refrained
# 4878 yes 35
# 4878 refrained 125
# 4878 not-logged-in 3
# 4878 excused 33
# 4878 no 4
# majority for topic  4878  voted for  refrained
# 4879 yes 60
# 4879 refrained 100
# 4879 not-logged-in 3
# 4879 excused 33
# 4879 no 4
# majority for topic  4879  voted for  refrained
# 4880 yes 57
# 4880 refrained 72
# 4880 not-logged-in 2
# 4880 excused 33
# 4880 no 36
# majority for topic  4880  voted for  refrained
# 4881 yes 139
# 4881 refrained 27
# 4881 not-logged-in 4
# 4881 excused 30
# 4881 no 0
# majority for topic  4881  voted for  yes
# 4882 yes 133
# 4882 refrained 34
# 4882 not-logged-in 2
# 4882 excused 30
# 4882 no 1
# majority for topic  4882  voted for  yes
# 4883 yes 150
# 4883 refrained 17
# 4883 not-logged-in 3
# 4883 excused 30
# 4883 no 0
# majority for topic  4883  voted for  yes
# 4884 yes 129
# 4884 refrained 34
# 4884 not-logged-in 4
# 4884 excused 29
# 4884 no 4
# majority for topic  4884  voted for  yes
# 4885 yes 143
# 4885 refrained 25
# 4885 not-logged-in 3
# 4885 excused 29
# 4885 no 0
# majority for topic  4885  voted for  yes
# 4886 yes 118
# 4886 refrained 21
# 4886 not-logged-in 28
# 4886 excused 33
# 4886 no 0
# majority for topic  4886  voted for  yes
# 4887 yes 176
# 4887 refrained 9
# 4887 not-logged-in 5
# 4887 excused 10
# 4887 no 0
# majority for topic  4887  voted for  yes
# 4888 yes 141
# 4888 refrained 12
# 4888 not-logged-in 4
# 4888 excused 10
# 4888 no 33
# majority for topic  4888  voted for  yes
# 4889 yes 83
# 4889 refrained 67
# 4889 not-logged-in 4
# 4889 excused 10
# 4889 no 36
# majority for topic  4889  voted for  yes
# 4890 yes 108
# 4890 refrained 60
# 4890 not-logged-in 4
# 4890 excused 10
# 4890 no 18
# majority for topic  4890  voted for  yes
# 4891 yes 68
# 4891 refrained 15
# 4891 not-logged-in 14
# 4891 excused 10
# 4891 no 93
# majority for topic  4891  voted for  no
# 4892 yes 132
# 4892 refrained 20
# 4892 not-logged-in 10
# 4892 excused 10
# 4892 no 28
# majority for topic  4892  voted for  yes
# 4893 yes 68
# 4893 refrained 16
# 4893 not-logged-in 7
# 4893 excused 10
# 4893 no 99
# majority for topic  4893  voted for  no
# 4894 yes 108
# 4894 refrained 0
# 4894 not-logged-in 4
# 4894 excused 10
# 4894 no 78
# majority for topic  4894  voted for  yes
# 4895 yes 79
# 4895 refrained 96
# 4895 not-logged-in 9
# 4895 excused 12
# 4895 no 4
# majority for topic  4895  voted for  refrained
# 4896 yes 186
# 4896 refrained 1
# 4896 not-logged-in 1
# 4896 excused 12
# 4896 no 0
# majority for topic  4896  voted for  yes
# 4897 yes 149
# 4897 refrained 12
# 4897 not-logged-in 24
# 4897 excused 12
# 4897 no 3
# majority for topic  4897  voted for  yes
# 4898 yes 121
# 4898 refrained 39
# 4898 not-logged-in 20
# 4898 excused 12
# 4898 no 8
# majority for topic  4898  voted for  yes
# 4899 yes 159
# 4899 refrained 11
# 4899 not-logged-in 18
# 4899 excused 12
# 4899 no 0
# majority for topic  4899  voted for  yes
# 4900 yes 73
# 4900 refrained 45
# 4900 not-logged-in 23
# 4900 excused 13
# 4900 no 46
# majority for topic  4900  voted for  yes
# 4901 yes 122
# 4901 refrained 43
# 4901 not-logged-in 21
# 4901 excused 13
# 4901 no 1
# majority for topic  4901  voted for  yes
# 4902 yes 154
# 4902 refrained 7
# 4902 not-logged-in 27
# 4902 excused 12
# 4902 no 0
# majority for topic  4902  voted for  yes
# 4903 yes 51
# 4903 refrained 43
# 4903 not-logged-in 22
# 4903 excused 12
# 4903 no 72
# majority for topic  4903  voted for  no
# 4904 yes 146
# 4904 refrained 10
# 4904 not-logged-in 21
# 4904 excused 12
# 4904 no 11
# majority for topic  4904  voted for  yes
# 4905 yes 154
# 4905 refrained 14
# 4905 not-logged-in 19
# 4905 excused 12
# 4905 no 1
# majority for topic  4905  voted for  yes
# 4906 yes 164
# 4906 refrained 8
# 4906 not-logged-in 16
# 4906 excused 12
# 4906 no 0
# majority for topic  4906  voted for  yes
# 4907 yes 166
# 4907 refrained 11
# 4907 not-logged-in 12
# 4907 excused 11
# 4907 no 0
# majority for topic  4907  voted for  yes
# 4908 yes 172
# 4908 refrained 6
# 4908 not-logged-in 11
# 4908 excused 11
# 4908 no 0
# majority for topic  4908  voted for  yes
# 4909 yes 170
# 4909 refrained 9
# 4909 not-logged-in 10
# 4909 excused 11
# 4909 no 0
# majority for topic  4909  voted for  yes
# 4910 yes 171
# 4910 refrained 9
# 4910 not-logged-in 9
# 4910 excused 11
# 4910 no 0
# majority for topic  4910  voted for  yes
# 4911 yes 127
# 4911 refrained 34
# 4911 not-logged-in 8
# 4911 excused 11
# 4911 no 20
# majority for topic  4911  voted for  yes
# 4912 yes 180
# 4912 refrained 5
# 4912 not-logged-in 3
# 4912 excused 12
# 4912 no 0
# majority for topic  4912  voted for  yes
# 4913 yes 182
# 4913 refrained 3
# 4913 not-logged-in 3
# 4913 excused 12
# 4913 no 0
# majority for topic  4913  voted for  yes
# 4914 yes 87
# 4914 refrained 80
# 4914 not-logged-in 4
# 4914 excused 12
# 4914 no 17
# majority for topic  4914  voted for  yes
# 4915 yes 69
# 4915 refrained 87
# 4915 not-logged-in 4
# 4915 excused 12
# 4915 no 28
# majority for topic  4915  voted for  refrained
# 4916 yes 53
# 4916 refrained 75
# 4916 not-logged-in 4
# 4916 excused 12
# 4916 no 56
# majority for topic  4916  voted for  refrained
# 4917 yes 41
# 4917 refrained 103
# 4917 not-logged-in 4
# 4917 excused 12
# 4917 no 40
# majority for topic  4917  voted for  refrained
# 4918 yes 179
# 4918 refrained 6
# 4918 not-logged-in 3
# 4918 excused 11
# 4918 no 1
# majority for topic  4918  voted for  yes
# 4919 yes 176
# 4919 refrained 10
# 4919 not-logged-in 3
# 4919 excused 11
# 4919 no 0
# majority for topic  4919  voted for  yes
# 4920 yes 162
# 4920 refrained 22
# 4920 not-logged-in 5
# 4920 excused 11
# 4920 no 0
# majority for topic  4920  voted for  yes
# 4921 yes 167
# 4921 refrained 17
# 4921 not-logged-in 5
# 4921 excused 11
# 4921 no 0
# majority for topic  4921  voted for  yes
# 4922 yes 174
# 4922 refrained 10
# 4922 not-logged-in 5
# 4922 excused 11
# 4922 no 0
# majority for topic  4922  voted for  yes
# 4923 yes 43
# 4923 refrained 52
# 4923 not-logged-in 27
# 4923 excused 11
# 4923 no 67
# majority for topic  4923  voted for  no
# 4924 yes 28
# 4924 refrained 113
# 4924 not-logged-in 15
# 4924 excused 11
# 4924 no 33
# majority for topic  4924  voted for  refrained
# 4925 yes 155
# 4925 refrained 16
# 4925 not-logged-in 15
# 4925 excused 11
# 4925 no 3
# majority for topic  4925  voted for  yes
# 4926 yes 154
# 4926 refrained 21
# 4926 not-logged-in 14
# 4926 excused 11
# 4926 no 0
# majority for topic  4926  voted for  yes
# 4927 yes 55
# 4927 refrained 79
# 4927 not-logged-in 12
# 4927 excused 11
# 4927 no 43
# majority for topic  4927  voted for  refrained
# 4928 yes 31
# 4928 refrained 105
# 4928 not-logged-in 14
# 4928 excused 11
# 4928 no 39
# majority for topic  4928  voted for  refrained
# 4929 yes 175
# 4929 refrained 2
# 4929 not-logged-in 12
# 4929 excused 11
# 4929 no 0
# majority for topic  4929  voted for  yes
# 4930 yes 153
# 4930 refrained 14
# 4930 not-logged-in 11
# 4930 excused 11
# 4930 no 11
# majority for topic  4930  voted for  yes
# 4931 yes 144
# 4931 refrained 27
# 4931 not-logged-in 11
# 4931 excused 11
# 4931 no 7
# majority for topic  4931  voted for  yes
# 4932 yes 158
# 4932 refrained 22
# 4932 not-logged-in 8
# 4932 excused 12
# 4932 no 0
# majority for topic  4932  voted for  yes
# 4933 yes 115
# 4933 refrained 25
# 4933 not-logged-in 14
# 4933 excused 12
# 4933 no 34
# majority for topic  4933  voted for  yes
# 4934 yes 160
# 4934 refrained 16
# 4934 not-logged-in 11
# 4934 excused 13
# 4934 no 0
# majority for topic  4934  voted for  yes
# 4935 yes 162
# 4935 refrained 14
# 4935 not-logged-in 11
# 4935 excused 13
# 4935 no 0
# majority for topic  4935  voted for  yes
# 4936 yes 164
# 4936 refrained 12
# 4936 not-logged-in 11
# 4936 excused 13
# 4936 no 0
# majority for topic  4936  voted for  yes
# 4937 yes 134
# 4937 refrained 9
# 4937 not-logged-in 30
# 4937 excused 21
# 4937 no 6
# majority for topic  4937  voted for  yes
# 4938 yes 141
# 4938 refrained 17
# 4938 not-logged-in 22
# 4938 excused 20
# 4938 no 0
# majority for topic  4938  voted for  yes
# 4939 yes 115
# 4939 refrained 43
# 4939 not-logged-in 18
# 4939 excused 23
# 4939 no 1
# majority for topic  4939  voted for  yes

# %% [markdown]
# textová podoba ale není příliš přehledná,

# %%
print(typesOfVotes)
df2 = pd.DataFrame.from_records(d, columns=['id', 'votingDate' , 'vote'])
df2['vote'].apply(lambda x : typesOfVotes.index(x)).plot.hist(title='total vote results')
plt.show()
# Out:
# ['yes', 'refrained', 'not-logged-in', 'excused', 'no']

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/matplotlib/axis.py in convert_units(self, x)
#    1519         try:
# -> 1520             ret = self.converter.convert(x, self.units, self)
#    1521         except Exception as e:
#
# ~/.local/lib/python3.6/site-packages/matplotlib/dates.py in convert(value, unit, axis)
#    1905         """
# -> 1906         return date2num(value)
#    1907
#
# ~/.local/lib/python3.6/site-packages/matplotlib/dates.py in date2num(d)
#     443             return d
# --> 444         return _to_ordinalf_np_vectorized(d)
#     445
#
# ~/.local/lib/python3.6/site-packages/numpy/lib/function_base.py in __call__(self, *args, **kwargs)
#    2107
# -> 2108         return self._vectorize_call(func=func, args=vargs)
#    2109
#
# ~/.local/lib/python3.6/site-packages/numpy/lib/function_base.py in _vectorize_call(self, func, args)
#    2191
# -> 2192             outputs = ufunc(*inputs)
#    2193
#
# ~/.local/lib/python3.6/site-packages/matplotlib/dates.py in _to_ordinalf(dt)
#     298         dt = dt.replace(tzinfo=None)
# --> 299     dt64 = np.datetime64(dt)
#     300     return _dt64_to_ordinalf(dt64)
#
# ValueError: Error parsing datetime string "yes" at position 0
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# <ipython-input-29-f2a2ddebacbb> in <module>
#       1 from pandas.plotting import lag_plot
# ----> 2 lag_plot(df2[['votingDate', 'vote']])
#       3 plt.show()
#
# ~/.local/lib/python3.6/site-packages/pandas/plotting/_misc.py in lag_plot(series, lag, ax, **kwds)
#     450     """
#     451     plot_backend = _get_plot_backend("matplotlib")
# --> 452     return plot_backend.lag_plot(series=series, lag=lag, ax=ax, **kwds)
#     453
#     454
#
# ~/.local/lib/python3.6/site-packages/pandas/plotting/_matplotlib/misc.py in lag_plot(series, lag, ax, **kwds)
#     399     ax.set_xlabel("y(t)")
#     400     ax.set_ylabel(f"y(t + {lag})")
# --> 401     ax.scatter(y1, y2, **kwds)
#     402     return ax
#     403
#
# ~/.local/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/.local/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4431
#    4432         self._process_unit_info(xdata=x, ydata=y, kwargs=kwargs)
# -> 4433         x = self.convert_xunits(x)
#    4434         y = self.convert_yunits(y)
#    4435
#
# ~/.local/lib/python3.6/site-packages/matplotlib/artist.py in convert_xunits(self, x)
#     173         if ax is None or ax.xaxis is None:
#     174             return x
# --> 175         return ax.xaxis.convert_units(x)
#     176
#     177     def convert_yunits(self, y):
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axis.py in convert_units(self, x)
#    1521         except Exception as e:
#    1522             raise munits.ConversionError('Failed to convert value(s) to axis '
# -> 1523                                          f'units: {x!r}') from e
#    1524         return ret
#    1525
#
# ConversionError: Failed to convert value(s) to axis units: array([[Timestamp('2017-11-20 13:53:00'), 'yes'],
#        [Timestamp('2017-11-20 13:53:00'), 'yes'],
#        [Timestamp('2017-11-20 14:47:00'), 'no'],
#        ...,
#        [Timestamp('2019-12-18 12:52:00'), 'yes'],
#        [Timestamp('2019-12-18 17:34:00'), 'yes'],
#        [Timestamp('2019-12-18 17:58:00'), 'yes']], dtype=object)
